# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)

img.shape
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# torch.Size([1, 28, 28])

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):

    '''
    for normalizing -0.5 and / 0.5 
    for denormalizing +0.5 and * 0.5 

    normalize :  x - 0.5 / 0.5 

    denormalize : x * 0.5 + 0.5 

    out  = (x+1)/2

    out  = x/2 + 1/2

    out = 0.5x + 0.5 

    '''

    out = (x + 1) / 2


    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)

plt.figure()

plt.imshow(img[0],cmap = 'gray')
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
type(mnist)
# Out:
# torchvision.datasets.mnist.MNIST

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([5, 9, 1, 2, 6, 4, 7, 1, 2, 3, 8, 7, 0, 8, 2, 1, 4, 6, 9, 3, 2, 3, 0, 0,
#         2, 9, 9, 0, 7, 9, 6, 3, 2, 5, 0, 7, 9, 0, 2, 0, 9, 9, 6, 4, 4, 0, 0, 8,
#         0, 0, 3, 2, 1, 2, 7, 0, 2, 3, 7, 8, 2, 5, 4, 0, 8, 2, 8, 2, 5, 8, 2, 5,
#         6, 5, 4, 9, 2, 8, 8, 9, 0, 2, 9, 1, 2, 6, 8, 6, 9, 6, 1, 3, 7, 6, 9, 8,
#         7, 3, 4, 0])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

#3 layer network.

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64


'''
#generator 



input - latent vector (128,1) or (latent_size,1)
output- 1,28,28 or 784
'''

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))



gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
#loss function

criterion = nn.BCELoss()

a,b = torch.FloatTensor([1]),torch.FloatTensor([0])

criterion(a,b)
# Out:
# tensor(100.)

# %%
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):

    '''
    while training the discriminator we need the images and the labels 
    for labels we use 1 for real and 0 for fake 
    output of discriminator is (batch_size,1)

    Here we also require the generated fake images 

    note: the descriminator doesnt take 2 images at the same time, its  a simple binary classifier 

    1. so feed real image then calculate the loss 
    2. then feed the fake image and calculate the loss


    we are not training the generator over here.


    '''


    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)


    fake_images = G(z)
    outputs = D(fake_images)

    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    '''
    by setting the labels to 1 the initial loss will be hight 
    as the optimizer (adam ) will try to reduce it. 

    '''
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)

    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %% [markdown]
# # Training Method

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0569, g_loss: 4.1068, D(x): 0.98, D(G(z)): 0.04
# Epoch [0/300], Step [400/600], d_loss: 0.1074, g_loss: 5.3806, D(x): 0.97, D(G(z)): 0.06
# Epoch [0/300], Step [600/600], d_loss: 0.1093, g_loss: 4.5519, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.2344, g_loss: 3.5849, D(x): 0.96, D(G(z)): 0.14
# Epoch [1/300], Step [400/600], d_loss: 0.2510, g_loss: 3.6366, D(x): 0.95, D(G(z)): 0.15
# Epoch [1/300], Step [600/600], d_loss: 0.7781, g_loss: 2.6721, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.2287, g_loss: 2.4379, D(x): 0.93, D(G(z)): 0.12
# Epoch [2/300], Step [400/600], d_loss: 0.6820, g_loss: 3.2651, D(x): 0.80, D(G(z)): 0.26
# Epoch [2/300], Step [600/600], d_loss: 0.1867, g_loss: 3.4617, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 2.2022, g_loss: 1.2075, D(x): 0.41, D(G(z)): 0.36
# Epoch [3/300], Step [400/600], d_loss: 0.7092, g_loss: 2.2421, D(x): 0.87, D(G(z)): 0.36
# Epoch [3/300], Step [600/600], d_loss: 0.5260, g_loss: 2.1267, D(x): 0.84, D(G(z)): 0.20
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 1.3384, g_loss: 2.0270, D(x): 0.67, D(G(z)): 0.40
# Epoch [4/300], Step [400/600], d_loss: 0.7129, g_loss: 2.8064, D(x): 0.82, D(G(z)): 0.29
# Epoch [4/300], Step [600/600], d_loss: 1.0412, g_loss: 2.4328, D(x): 0.73, D(G(z)): 0.36
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 1.5041, g_loss: 1.3710, D(x): 0.59, D(G(z)): 0.33
# Epoch [5/300], Step [400/600], d_loss: 0.1890, g_loss: 3.5200, D(x): 0.91, D(G(z)): 0.07
# Epoch [5/300], Step [600/600], d_loss: 0.4084, g_loss: 2.1769, D(x): 0.90, D(G(z)): 0.20
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.2653, g_loss: 3.2666, D(x): 0.91, D(G(z)): 0.12
# Epoch [6/300], Step [400/600], d_loss: 0.3544, g_loss: 3.1184, D(x): 0.95, D(G(z)): 0.18
# Epoch [6/300], Step [600/600], d_loss: 0.2015, g_loss: 4.1705, D(x): 0.89, D(G(z)): 0.04
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.3298, g_loss: 3.1342, D(x): 0.90, D(G(z)): 0.09
# Epoch [7/300], Step [400/600], d_loss: 0.1802, g_loss: 3.8862, D(x): 0.94, D(G(z)): 0.07
# Epoch [7/300], Step [600/600], d_loss: 0.3557, g_loss: 4.8464, D(x): 0.88, D(G(z)): 0.07
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.2016, g_loss: 4.6160, D(x): 0.97, D(G(z)): 0.11
# Epoch [8/300], Step [400/600], d_loss: 0.4366, g_loss: 3.6356, D(x): 0.93, D(G(z)): 0.20
# Epoch [8/300], Step [600/600], d_loss: 0.1372, g_loss: 5.4708, D(x): 0.95, D(G(z)): 0.06
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.2084, g_loss: 5.7445, D(x): 0.92, D(G(z)): 0.04
# Epoch [9/300], Step [400/600], d_loss: 0.0350, g_loss: 6.1092, D(x): 0.99, D(G(z)): 0.02
# Epoch [9/300], Step [600/600], d_loss: 0.3703, g_loss: 4.4213, D(x): 0.94, D(G(z)): 0.18
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.1622, g_loss: 4.9579, D(x): 0.97, D(G(z)): 0.10
# Epoch [10/300], Step [400/600], d_loss: 0.2584, g_loss: 5.5540, D(x): 0.93, D(G(z)): 0.06
# Epoch [10/300], Step [600/600], d_loss: 0.1087, g_loss: 4.9351, D(x): 0.97, D(G(z)): 0.04
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1885, g_loss: 4.1837, D(x): 0.94, D(G(z)): 0.04
# Epoch [11/300], Step [400/600], d_loss: 0.2848, g_loss: 4.8244, D(x): 0.92, D(G(z)): 0.03
# Epoch [11/300], Step [600/600], d_loss: 0.1842, g_loss: 4.8749, D(x): 0.97, D(G(z)): 0.13
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.2885, g_loss: 5.1732, D(x): 0.89, D(G(z)): 0.03
# Epoch [12/300], Step [400/600], d_loss: 0.2921, g_loss: 3.0326, D(x): 0.93, D(G(z)): 0.07
# Epoch [12/300], Step [600/600], d_loss: 0.1908, g_loss: 4.2411, D(x): 0.96, D(G(z)): 0.11
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.2993, g_loss: 4.7538, D(x): 0.94, D(G(z)): 0.05
# Epoch [13/300], Step [400/600], d_loss: 0.0999, g_loss: 3.9318, D(x): 0.98, D(G(z)): 0.06
# Epoch [13/300], Step [600/600], d_loss: 0.1043, g_loss: 5.8938, D(x): 0.94, D(G(z)): 0.02
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.2872, g_loss: 4.4387, D(x): 0.89, D(G(z)): 0.03
# Epoch [14/300], Step [400/600], d_loss: 0.1414, g_loss: 4.5787, D(x): 0.95, D(G(z)): 0.02
# Epoch [14/300], Step [600/600], d_loss: 0.2253, g_loss: 5.3242, D(x): 0.96, D(G(z)): 0.10
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.1507, g_loss: 5.7256, D(x): 0.96, D(G(z)): 0.05
# Epoch [15/300], Step [400/600], d_loss: 0.0897, g_loss: 4.8557, D(x): 0.98, D(G(z)): 0.05
# Epoch [15/300], Step [600/600], d_loss: 0.0999, g_loss: 5.6341, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.1151, g_loss: 8.3193, D(x): 0.94, D(G(z)): 0.01
# Epoch [16/300], Step [400/600], d_loss: 0.3924, g_loss: 4.4128, D(x): 0.97, D(G(z)): 0.21
# Epoch [16/300], Step [600/600], d_loss: 0.2108, g_loss: 4.6594, D(x): 0.93, D(G(z)): 0.03
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.2684, g_loss: 5.3684, D(x): 0.97, D(G(z)): 0.16
# Epoch [17/300], Step [400/600], d_loss: 0.1864, g_loss: 6.2622, D(x): 0.91, D(G(z)): 0.01
# Epoch [17/300], Step [600/600], d_loss: 0.2309, g_loss: 5.1176, D(x): 0.93, D(G(z)): 0.09
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.3523, g_loss: 6.6953, D(x): 0.88, D(G(z)): 0.02
# Epoch [18/300], Step [400/600], d_loss: 0.1868, g_loss: 4.9197, D(x): 0.95, D(G(z)): 0.09
# Epoch [18/300], Step [600/600], d_loss: 0.2915, g_loss: 3.9482, D(x): 0.91, D(G(z)): 0.04
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.2162, g_loss: 4.7732, D(x): 0.96, D(G(z)): 0.07
# Epoch [19/300], Step [400/600], d_loss: 0.2010, g_loss: 4.8615, D(x): 0.94, D(G(z)): 0.08
# Epoch [19/300], Step [600/600], d_loss: 0.4249, g_loss: 4.6309, D(x): 0.86, D(G(z)): 0.09
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2715, g_loss: 3.3481, D(x): 0.96, D(G(z)): 0.12
# Epoch [20/300], Step [400/600], d_loss: 0.3050, g_loss: 4.7458, D(x): 0.92, D(G(z)): 0.10
# Epoch [20/300], Step [600/600], d_loss: 0.2719, g_loss: 3.6476, D(x): 0.94, D(G(z)): 0.11
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1950, g_loss: 4.6385, D(x): 0.95, D(G(z)): 0.05
# Epoch [21/300], Step [400/600], d_loss: 0.2575, g_loss: 5.6507, D(x): 0.90, D(G(z)): 0.01
# Epoch [21/300], Step [600/600], d_loss: 0.2155, g_loss: 4.0223, D(x): 0.95, D(G(z)): 0.11
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.3049, g_loss: 4.0785, D(x): 0.93, D(G(z)): 0.09
# Epoch [22/300], Step [400/600], d_loss: 0.1700, g_loss: 4.1650, D(x): 0.94, D(G(z)): 0.06
# Epoch [22/300], Step [600/600], d_loss: 0.1845, g_loss: 4.2328, D(x): 0.94, D(G(z)): 0.04
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.1847, g_loss: 4.4804, D(x): 0.94, D(G(z)): 0.05
# Epoch [23/300], Step [400/600], d_loss: 0.2416, g_loss: 4.3366, D(x): 0.92, D(G(z)): 0.03
# Epoch [23/300], Step [600/600], d_loss: 0.3915, g_loss: 5.1426, D(x): 0.96, D(G(z)): 0.18
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.2801, g_loss: 4.1301, D(x): 0.92, D(G(z)): 0.11
# Epoch [24/300], Step [400/600], d_loss: 0.4613, g_loss: 3.9202, D(x): 0.85, D(G(z)): 0.03
# Epoch [24/300], Step [600/600], d_loss: 0.3959, g_loss: 4.3505, D(x): 0.86, D(G(z)): 0.08
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.5393, g_loss: 3.7251, D(x): 0.87, D(G(z)): 0.04
# Epoch [25/300], Step [400/600], d_loss: 0.2441, g_loss: 4.4755, D(x): 0.94, D(G(z)): 0.09
# Epoch [25/300], Step [600/600], d_loss: 0.2478, g_loss: 6.5926, D(x): 0.91, D(G(z)): 0.05
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.2494, g_loss: 3.9103, D(x): 0.93, D(G(z)): 0.10
# Epoch [26/300], Step [400/600], d_loss: 0.2384, g_loss: 4.8194, D(x): 0.95, D(G(z)): 0.12
# Epoch [26/300], Step [600/600], d_loss: 0.2448, g_loss: 4.5584, D(x): 0.89, D(G(z)): 0.04
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.2054, g_loss: 4.8790, D(x): 0.93, D(G(z)): 0.08
# Epoch [27/300], Step [400/600], d_loss: 0.3848, g_loss: 4.5181, D(x): 0.86, D(G(z)): 0.09
# Epoch [27/300], Step [600/600], d_loss: 0.2301, g_loss: 3.0605, D(x): 0.94, D(G(z)): 0.09
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.1762, g_loss: 4.6703, D(x): 0.93, D(G(z)): 0.06
# Epoch [28/300], Step [400/600], d_loss: 0.2999, g_loss: 3.0087, D(x): 0.89, D(G(z)): 0.08
# Epoch [28/300], Step [600/600], d_loss: 0.5859, g_loss: 3.1149, D(x): 0.83, D(G(z)): 0.09
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2631, g_loss: 4.1318, D(x): 0.93, D(G(z)): 0.11
# Epoch [29/300], Step [400/600], d_loss: 0.2719, g_loss: 3.4982, D(x): 0.97, D(G(z)): 0.15
# Epoch [29/300], Step [600/600], d_loss: 0.3231, g_loss: 4.2370, D(x): 0.88, D(G(z)): 0.03
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.2532, g_loss: 2.9541, D(x): 0.92, D(G(z)): 0.08
# Epoch [30/300], Step [400/600], d_loss: 0.3204, g_loss: 4.9378, D(x): 0.93, D(G(z)): 0.16
# Epoch [30/300], Step [600/600], d_loss: 0.5231, g_loss: 3.1115, D(x): 0.87, D(G(z)): 0.18
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.5288, g_loss: 3.3447, D(x): 0.82, D(G(z)): 0.10
# Epoch [31/300], Step [400/600], d_loss: 0.4320, g_loss: 3.9692, D(x): 0.85, D(G(z)): 0.08
# Epoch [31/300], Step [600/600], d_loss: 0.4870, g_loss: 4.2937, D(x): 0.84, D(G(z)): 0.09
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.4435, g_loss: 3.4417, D(x): 0.84, D(G(z)): 0.06
# Epoch [32/300], Step [400/600], d_loss: 0.3659, g_loss: 3.0091, D(x): 0.92, D(G(z)): 0.18
# Epoch [32/300], Step [600/600], d_loss: 0.2552, g_loss: 3.9927, D(x): 0.91, D(G(z)): 0.08
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.3574, g_loss: 3.0444, D(x): 0.88, D(G(z)): 0.12
# Epoch [33/300], Step [400/600], d_loss: 0.5241, g_loss: 3.3978, D(x): 0.85, D(G(z)): 0.15
# Epoch [33/300], Step [600/600], d_loss: 0.4819, g_loss: 2.5623, D(x): 0.87, D(G(z)): 0.17
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4491, g_loss: 2.6043, D(x): 0.82, D(G(z)): 0.09
# Epoch [34/300], Step [400/600], d_loss: 0.5271, g_loss: 2.8530, D(x): 0.90, D(G(z)): 0.24
# Epoch [34/300], Step [600/600], d_loss: 0.3755, g_loss: 3.2271, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.4064, g_loss: 4.2424, D(x): 0.87, D(G(z)): 0.13
# Epoch [35/300], Step [400/600], d_loss: 0.4251, g_loss: 3.2417, D(x): 0.85, D(G(z)): 0.11
# Epoch [35/300], Step [600/600], d_loss: 0.5398, g_loss: 3.6200, D(x): 0.83, D(G(z)): 0.12
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.3668, g_loss: 3.0156, D(x): 0.89, D(G(z)): 0.11
# Epoch [36/300], Step [400/600], d_loss: 0.5289, g_loss: 3.0434, D(x): 0.85, D(G(z)): 0.15
# Epoch [36/300], Step [600/600], d_loss: 0.4514, g_loss: 2.7359, D(x): 0.93, D(G(z)): 0.23
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4119, g_loss: 2.8657, D(x): 0.89, D(G(z)): 0.16
# Epoch [37/300], Step [400/600], d_loss: 0.7806, g_loss: 3.6004, D(x): 0.96, D(G(z)): 0.37
# Epoch [37/300], Step [600/600], d_loss: 0.3682, g_loss: 2.8111, D(x): 0.89, D(G(z)): 0.11
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.6101, g_loss: 2.2904, D(x): 0.90, D(G(z)): 0.28
# Epoch [38/300], Step [400/600], d_loss: 0.4082, g_loss: 3.4969, D(x): 0.80, D(G(z)): 0.06
# Epoch [38/300], Step [600/600], d_loss: 0.4136, g_loss: 3.5344, D(x): 0.92, D(G(z)): 0.19
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.3565, g_loss: 4.0961, D(x): 0.88, D(G(z)): 0.08
# Epoch [39/300], Step [400/600], d_loss: 0.2284, g_loss: 3.8889, D(x): 0.94, D(G(z)): 0.13
# Epoch [39/300], Step [600/600], d_loss: 0.3347, g_loss: 4.1036, D(x): 0.87, D(G(z)): 0.09
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.3972, g_loss: 3.4633, D(x): 0.85, D(G(z)): 0.10
# Epoch [40/300], Step [400/600], d_loss: 0.4771, g_loss: 2.4168, D(x): 0.86, D(G(z)): 0.16
# Epoch [40/300], Step [600/600], d_loss: 0.3428, g_loss: 2.9884, D(x): 0.92, D(G(z)): 0.15
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.5152, g_loss: 2.9263, D(x): 0.94, D(G(z)): 0.28
# Epoch [41/300], Step [400/600], d_loss: 0.5083, g_loss: 2.1640, D(x): 0.81, D(G(z)): 0.12
# Epoch [41/300], Step [600/600], d_loss: 0.6333, g_loss: 2.4008, D(x): 0.92, D(G(z)): 0.29
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.6003, g_loss: 2.5036, D(x): 0.77, D(G(z)): 0.13
# Epoch [42/300], Step [400/600], d_loss: 0.4946, g_loss: 2.7737, D(x): 0.82, D(G(z)): 0.12
# Epoch [42/300], Step [600/600], d_loss: 0.7218, g_loss: 3.0275, D(x): 0.73, D(G(z)): 0.10
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.3871, g_loss: 3.1666, D(x): 0.85, D(G(z)): 0.10
# Epoch [43/300], Step [400/600], d_loss: 0.5042, g_loss: 2.9108, D(x): 0.88, D(G(z)): 0.22
# Epoch [43/300], Step [600/600], d_loss: 0.4815, g_loss: 2.2234, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5795, g_loss: 2.6487, D(x): 0.82, D(G(z)): 0.16
# Epoch [44/300], Step [400/600], d_loss: 0.6019, g_loss: 2.1138, D(x): 0.86, D(G(z)): 0.25
# Epoch [44/300], Step [600/600], d_loss: 0.4227, g_loss: 2.7790, D(x): 0.89, D(G(z)): 0.18
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.7408, g_loss: 2.8220, D(x): 0.75, D(G(z)): 0.15
# Epoch [45/300], Step [400/600], d_loss: 0.6066, g_loss: 3.2312, D(x): 0.79, D(G(z)): 0.14
# Epoch [45/300], Step [600/600], d_loss: 0.7074, g_loss: 2.8150, D(x): 0.75, D(G(z)): 0.16
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.6009, g_loss: 2.2115, D(x): 0.76, D(G(z)): 0.13
# Epoch [46/300], Step [400/600], d_loss: 0.4151, g_loss: 3.0402, D(x): 0.83, D(G(z)): 0.10
# Epoch [46/300], Step [600/600], d_loss: 0.3831, g_loss: 2.6274, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.6051, g_loss: 3.0565, D(x): 0.76, D(G(z)): 0.13
# Epoch [47/300], Step [400/600], d_loss: 0.4475, g_loss: 2.8306, D(x): 0.94, D(G(z)): 0.24
# Epoch [47/300], Step [600/600], d_loss: 0.4863, g_loss: 3.4580, D(x): 0.84, D(G(z)): 0.12
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.4093, g_loss: 3.3318, D(x): 0.87, D(G(z)): 0.14
# Epoch [48/300], Step [400/600], d_loss: 0.5192, g_loss: 3.0761, D(x): 0.81, D(G(z)): 0.14
# Epoch [48/300], Step [600/600], d_loss: 0.5331, g_loss: 3.1304, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.2964, g_loss: 3.2539, D(x): 0.94, D(G(z)): 0.16
# Epoch [49/300], Step [400/600], d_loss: 0.4437, g_loss: 2.6393, D(x): 0.83, D(G(z)): 0.13
# Epoch [49/300], Step [600/600], d_loss: 0.4116, g_loss: 3.2161, D(x): 0.84, D(G(z)): 0.13
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.5938, g_loss: 2.7188, D(x): 0.91, D(G(z)): 0.28
# Epoch [50/300], Step [400/600], d_loss: 0.5180, g_loss: 3.2213, D(x): 0.88, D(G(z)): 0.21
# Epoch [50/300], Step [600/600], d_loss: 0.5671, g_loss: 2.5529, D(x): 0.84, D(G(z)): 0.23
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.8065, g_loss: 1.8019, D(x): 0.76, D(G(z)): 0.19
# Epoch [51/300], Step [400/600], d_loss: 0.6300, g_loss: 3.0862, D(x): 0.81, D(G(z)): 0.16
# Epoch [51/300], Step [600/600], d_loss: 0.5033, g_loss: 2.7268, D(x): 0.79, D(G(z)): 0.10
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.4574, g_loss: 2.5302, D(x): 0.88, D(G(z)): 0.14
# Epoch [52/300], Step [400/600], d_loss: 0.4153, g_loss: 3.4330, D(x): 0.83, D(G(z)): 0.08
# Epoch [52/300], Step [600/600], d_loss: 0.5768, g_loss: 2.4101, D(x): 0.85, D(G(z)): 0.21
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.7440, g_loss: 3.2097, D(x): 0.78, D(G(z)): 0.18
# Epoch [53/300], Step [400/600], d_loss: 0.6802, g_loss: 2.8002, D(x): 0.73, D(G(z)): 0.10
# Epoch [53/300], Step [600/600], d_loss: 0.6869, g_loss: 3.2623, D(x): 0.85, D(G(z)): 0.26
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.6303, g_loss: 2.7969, D(x): 0.83, D(G(z)): 0.22
# Epoch [54/300], Step [400/600], d_loss: 0.5748, g_loss: 2.9960, D(x): 0.77, D(G(z)): 0.13
# Epoch [54/300], Step [600/600], d_loss: 0.5756, g_loss: 2.5914, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.7170, g_loss: 1.4642, D(x): 0.77, D(G(z)): 0.20
# Epoch [55/300], Step [400/600], d_loss: 0.5809, g_loss: 2.2792, D(x): 0.79, D(G(z)): 0.12
# Epoch [55/300], Step [600/600], d_loss: 0.3989, g_loss: 3.1548, D(x): 0.85, D(G(z)): 0.14
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.4651, g_loss: 2.7175, D(x): 0.87, D(G(z)): 0.19
# Epoch [56/300], Step [400/600], d_loss: 0.4456, g_loss: 2.2707, D(x): 0.86, D(G(z)): 0.17
# Epoch [56/300], Step [600/600], d_loss: 0.4868, g_loss: 2.9836, D(x): 0.84, D(G(z)): 0.17
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.5908, g_loss: 2.4438, D(x): 0.82, D(G(z)): 0.21
# Epoch [57/300], Step [400/600], d_loss: 0.6608, g_loss: 3.3358, D(x): 0.74, D(G(z)): 0.11
# Epoch [57/300], Step [600/600], d_loss: 0.5231, g_loss: 2.5054, D(x): 0.87, D(G(z)): 0.24
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.5967, g_loss: 2.2590, D(x): 0.78, D(G(z)): 0.18
# Epoch [58/300], Step [400/600], d_loss: 0.5325, g_loss: 2.0311, D(x): 0.86, D(G(z)): 0.22
# Epoch [58/300], Step [600/600], d_loss: 0.5910, g_loss: 2.9952, D(x): 0.82, D(G(z)): 0.22
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.7107, g_loss: 2.1318, D(x): 0.72, D(G(z)): 0.17
# Epoch [59/300], Step [400/600], d_loss: 0.5814, g_loss: 2.1603, D(x): 0.81, D(G(z)): 0.20
# Epoch [59/300], Step [600/600], d_loss: 0.6044, g_loss: 2.6582, D(x): 0.80, D(G(z)): 0.18
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.7701, g_loss: 1.5375, D(x): 0.76, D(G(z)): 0.22
# Epoch [60/300], Step [400/600], d_loss: 0.5987, g_loss: 2.8346, D(x): 0.78, D(G(z)): 0.16
# Epoch [60/300], Step [600/600], d_loss: 0.6443, g_loss: 2.7576, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.8565, g_loss: 2.1863, D(x): 0.87, D(G(z)): 0.36
# Epoch [61/300], Step [400/600], d_loss: 0.7354, g_loss: 2.0751, D(x): 0.76, D(G(z)): 0.21
# Epoch [61/300], Step [600/600], d_loss: 0.4998, g_loss: 2.6503, D(x): 0.80, D(G(z)): 0.16
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.5603, g_loss: 1.9743, D(x): 0.79, D(G(z)): 0.17
# Epoch [62/300], Step [400/600], d_loss: 0.5538, g_loss: 2.0653, D(x): 0.85, D(G(z)): 0.24
# Epoch [62/300], Step [600/600], d_loss: 0.6515, g_loss: 2.3296, D(x): 0.81, D(G(z)): 0.21
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.6609, g_loss: 2.6012, D(x): 0.89, D(G(z)): 0.32
# Epoch [63/300], Step [400/600], d_loss: 0.5939, g_loss: 2.4456, D(x): 0.80, D(G(z)): 0.19
# Epoch [63/300], Step [600/600], d_loss: 0.4500, g_loss: 2.5536, D(x): 0.83, D(G(z)): 0.16
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6775, g_loss: 2.7028, D(x): 0.78, D(G(z)): 0.19
# Epoch [64/300], Step [400/600], d_loss: 0.6551, g_loss: 1.9254, D(x): 0.85, D(G(z)): 0.27
# Epoch [64/300], Step [600/600], d_loss: 0.6799, g_loss: 2.3795, D(x): 0.82, D(G(z)): 0.25
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.6906, g_loss: 2.6645, D(x): 0.73, D(G(z)): 0.17
# Epoch [65/300], Step [400/600], d_loss: 0.5422, g_loss: 3.0048, D(x): 0.88, D(G(z)): 0.25
# Epoch [65/300], Step [600/600], d_loss: 0.6185, g_loss: 2.5804, D(x): 0.81, D(G(z)): 0.22
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.5279, g_loss: 2.4794, D(x): 0.83, D(G(z)): 0.20
# Epoch [66/300], Step [400/600], d_loss: 0.6055, g_loss: 2.7211, D(x): 0.79, D(G(z)): 0.18
# Epoch [66/300], Step [600/600], d_loss: 0.9022, g_loss: 2.3470, D(x): 0.68, D(G(z)): 0.18
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.7168, g_loss: 2.6680, D(x): 0.84, D(G(z)): 0.31
# Epoch [67/300], Step [400/600], d_loss: 0.7620, g_loss: 1.9973, D(x): 0.74, D(G(z)): 0.20
# Epoch [67/300], Step [600/600], d_loss: 0.6033, g_loss: 2.2738, D(x): 0.81, D(G(z)): 0.23
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.6835, g_loss: 2.5832, D(x): 0.75, D(G(z)): 0.18
# Epoch [68/300], Step [400/600], d_loss: 0.8259, g_loss: 2.0397, D(x): 0.73, D(G(z)): 0.27
# Epoch [68/300], Step [600/600], d_loss: 0.7563, g_loss: 1.8625, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.6165, g_loss: 2.2795, D(x): 0.80, D(G(z)): 0.21
# Epoch [69/300], Step [400/600], d_loss: 0.5728, g_loss: 2.6539, D(x): 0.78, D(G(z)): 0.16
# Epoch [69/300], Step [600/600], d_loss: 0.6548, g_loss: 2.2779, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.7362, g_loss: 1.6060, D(x): 0.82, D(G(z)): 0.31
# Epoch [70/300], Step [400/600], d_loss: 0.6597, g_loss: 2.6357, D(x): 0.83, D(G(z)): 0.26
# Epoch [70/300], Step [600/600], d_loss: 0.7286, g_loss: 1.9746, D(x): 0.80, D(G(z)): 0.27
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.6104, g_loss: 2.3488, D(x): 0.79, D(G(z)): 0.22
# Epoch [71/300], Step [400/600], d_loss: 0.5292, g_loss: 2.6560, D(x): 0.80, D(G(z)): 0.15
# Epoch [71/300], Step [600/600], d_loss: 0.7650, g_loss: 1.6981, D(x): 0.82, D(G(z)): 0.32
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.8593, g_loss: 2.3130, D(x): 0.67, D(G(z)): 0.16
# Epoch [72/300], Step [400/600], d_loss: 0.7816, g_loss: 1.8541, D(x): 0.73, D(G(z)): 0.23
# Epoch [72/300], Step [600/600], d_loss: 0.9281, g_loss: 1.7155, D(x): 0.84, D(G(z)): 0.41
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.5681, g_loss: 2.0742, D(x): 0.85, D(G(z)): 0.26
# Epoch [73/300], Step [400/600], d_loss: 0.6501, g_loss: 1.9766, D(x): 0.75, D(G(z)): 0.20
# Epoch [73/300], Step [600/600], d_loss: 0.6885, g_loss: 2.1267, D(x): 0.83, D(G(z)): 0.26
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.8634, g_loss: 2.7719, D(x): 0.71, D(G(z)): 0.23
# Epoch [74/300], Step [400/600], d_loss: 0.5341, g_loss: 2.5343, D(x): 0.82, D(G(z)): 0.21
# Epoch [74/300], Step [600/600], d_loss: 0.5916, g_loss: 2.2934, D(x): 0.81, D(G(z)): 0.21
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.5296, g_loss: 2.0634, D(x): 0.83, D(G(z)): 0.18
# Epoch [75/300], Step [400/600], d_loss: 0.7103, g_loss: 2.4678, D(x): 0.76, D(G(z)): 0.20
# Epoch [75/300], Step [600/600], d_loss: 0.6041, g_loss: 2.6250, D(x): 0.85, D(G(z)): 0.28
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.6013, g_loss: 2.7095, D(x): 0.84, D(G(z)): 0.25
# Epoch [76/300], Step [400/600], d_loss: 0.7113, g_loss: 1.8411, D(x): 0.78, D(G(z)): 0.24
# Epoch [76/300], Step [600/600], d_loss: 0.4684, g_loss: 2.3920, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.7976, g_loss: 2.1381, D(x): 0.74, D(G(z)): 0.28
# Epoch [77/300], Step [400/600], d_loss: 0.6427, g_loss: 2.1197, D(x): 0.79, D(G(z)): 0.24
# Epoch [77/300], Step [600/600], d_loss: 0.9972, g_loss: 2.1587, D(x): 0.67, D(G(z)): 0.20
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.8227, g_loss: 2.1136, D(x): 0.71, D(G(z)): 0.20
# Epoch [78/300], Step [400/600], d_loss: 0.6297, g_loss: 2.2932, D(x): 0.83, D(G(z)): 0.27
# Epoch [78/300], Step [600/600], d_loss: 0.5807, g_loss: 2.0404, D(x): 0.85, D(G(z)): 0.25
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6218, g_loss: 2.4253, D(x): 0.77, D(G(z)): 0.21
# Epoch [79/300], Step [400/600], d_loss: 0.7236, g_loss: 1.8959, D(x): 0.75, D(G(z)): 0.25
# Epoch [79/300], Step [600/600], d_loss: 0.6301, g_loss: 2.2483, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.6581, g_loss: 2.2856, D(x): 0.75, D(G(z)): 0.18
# Epoch [80/300], Step [400/600], d_loss: 0.9762, g_loss: 2.1595, D(x): 0.81, D(G(z)): 0.40
# Epoch [80/300], Step [600/600], d_loss: 0.7124, g_loss: 2.0618, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.5237, g_loss: 2.4704, D(x): 0.79, D(G(z)): 0.15
# Epoch [81/300], Step [400/600], d_loss: 0.6805, g_loss: 1.9824, D(x): 0.84, D(G(z)): 0.29
# Epoch [81/300], Step [600/600], d_loss: 0.7374, g_loss: 2.2029, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.8102, g_loss: 2.1535, D(x): 0.76, D(G(z)): 0.29
# Epoch [82/300], Step [400/600], d_loss: 0.8669, g_loss: 1.6061, D(x): 0.68, D(G(z)): 0.23
# Epoch [82/300], Step [600/600], d_loss: 0.6443, g_loss: 2.3127, D(x): 0.81, D(G(z)): 0.22
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.8574, g_loss: 1.9321, D(x): 0.85, D(G(z)): 0.40
# Epoch [83/300], Step [400/600], d_loss: 0.6668, g_loss: 2.0824, D(x): 0.83, D(G(z)): 0.26
# Epoch [83/300], Step [600/600], d_loss: 0.7178, g_loss: 2.0358, D(x): 0.79, D(G(z)): 0.31
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.9287, g_loss: 2.0706, D(x): 0.69, D(G(z)): 0.26
# Epoch [84/300], Step [400/600], d_loss: 0.5350, g_loss: 2.4275, D(x): 0.81, D(G(z)): 0.22
# Epoch [84/300], Step [600/600], d_loss: 0.6364, g_loss: 2.6177, D(x): 0.83, D(G(z)): 0.24
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.8149, g_loss: 2.3687, D(x): 0.69, D(G(z)): 0.17
# Epoch [85/300], Step [400/600], d_loss: 0.6790, g_loss: 2.0912, D(x): 0.78, D(G(z)): 0.23
# Epoch [85/300], Step [600/600], d_loss: 0.8031, g_loss: 1.6396, D(x): 0.78, D(G(z)): 0.29
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.8002, g_loss: 2.7366, D(x): 0.69, D(G(z)): 0.21
# Epoch [86/300], Step [400/600], d_loss: 0.7828, g_loss: 2.1907, D(x): 0.72, D(G(z)): 0.23
# Epoch [86/300], Step [600/600], d_loss: 0.7214, g_loss: 2.3850, D(x): 0.78, D(G(z)): 0.26
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.6553, g_loss: 1.8207, D(x): 0.77, D(G(z)): 0.22
# Epoch [87/300], Step [400/600], d_loss: 0.9052, g_loss: 1.5608, D(x): 0.75, D(G(z)): 0.27
# Epoch [87/300], Step [600/600], d_loss: 0.8607, g_loss: 2.2069, D(x): 0.68, D(G(z)): 0.22
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.6696, g_loss: 2.2782, D(x): 0.79, D(G(z)): 0.24
# Epoch [88/300], Step [400/600], d_loss: 0.8984, g_loss: 1.7932, D(x): 0.75, D(G(z)): 0.31
# Epoch [88/300], Step [600/600], d_loss: 0.5002, g_loss: 2.4235, D(x): 0.85, D(G(z)): 0.23
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.6245, g_loss: 1.6166, D(x): 0.83, D(G(z)): 0.27
# Epoch [89/300], Step [400/600], d_loss: 0.7069, g_loss: 2.1959, D(x): 0.76, D(G(z)): 0.22
# Epoch [89/300], Step [600/600], d_loss: 0.6894, g_loss: 2.0511, D(x): 0.81, D(G(z)): 0.26
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.6556, g_loss: 2.0801, D(x): 0.79, D(G(z)): 0.24
# Epoch [90/300], Step [400/600], d_loss: 0.6326, g_loss: 1.5255, D(x): 0.80, D(G(z)): 0.24
# Epoch [90/300], Step [600/600], d_loss: 0.8337, g_loss: 1.9626, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.7621, g_loss: 2.5933, D(x): 0.77, D(G(z)): 0.25
# Epoch [91/300], Step [400/600], d_loss: 0.5793, g_loss: 2.1392, D(x): 0.84, D(G(z)): 0.24
# Epoch [91/300], Step [600/600], d_loss: 0.7470, g_loss: 2.1033, D(x): 0.71, D(G(z)): 0.21
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.7183, g_loss: 1.9168, D(x): 0.86, D(G(z)): 0.32
# Epoch [92/300], Step [400/600], d_loss: 0.7924, g_loss: 1.9609, D(x): 0.80, D(G(z)): 0.30
# Epoch [92/300], Step [600/600], d_loss: 0.6254, g_loss: 1.9297, D(x): 0.82, D(G(z)): 0.27
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.8128, g_loss: 2.0137, D(x): 0.77, D(G(z)): 0.30
# Epoch [93/300], Step [400/600], d_loss: 0.6627, g_loss: 2.1602, D(x): 0.79, D(G(z)): 0.23
# Epoch [93/300], Step [600/600], d_loss: 0.7684, g_loss: 2.4091, D(x): 0.73, D(G(z)): 0.21
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.7954, g_loss: 1.7816, D(x): 0.76, D(G(z)): 0.25
# Epoch [94/300], Step [400/600], d_loss: 0.8103, g_loss: 1.5125, D(x): 0.78, D(G(z)): 0.31
# Epoch [94/300], Step [600/600], d_loss: 0.7759, g_loss: 1.9633, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.6398, g_loss: 2.7292, D(x): 0.74, D(G(z)): 0.16
# Epoch [95/300], Step [400/600], d_loss: 0.6812, g_loss: 1.8012, D(x): 0.77, D(G(z)): 0.22
# Epoch [95/300], Step [600/600], d_loss: 0.7638, g_loss: 2.6591, D(x): 0.78, D(G(z)): 0.27
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.8673, g_loss: 2.3745, D(x): 0.67, D(G(z)): 0.21
# Epoch [96/300], Step [400/600], d_loss: 1.1167, g_loss: 1.5152, D(x): 0.76, D(G(z)): 0.43
# Epoch [96/300], Step [600/600], d_loss: 0.7729, g_loss: 1.7548, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.7051, g_loss: 2.2232, D(x): 0.71, D(G(z)): 0.17
# Epoch [97/300], Step [400/600], d_loss: 1.2094, g_loss: 2.0515, D(x): 0.69, D(G(z)): 0.36
# Epoch [97/300], Step [600/600], d_loss: 0.7914, g_loss: 2.2715, D(x): 0.71, D(G(z)): 0.21
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.7122, g_loss: 1.9024, D(x): 0.77, D(G(z)): 0.24
# Epoch [98/300], Step [400/600], d_loss: 0.7856, g_loss: 2.4464, D(x): 0.71, D(G(z)): 0.22
# Epoch [98/300], Step [600/600], d_loss: 0.9599, g_loss: 1.5064, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.7039, g_loss: 2.0414, D(x): 0.72, D(G(z)): 0.20
# Epoch [99/300], Step [400/600], d_loss: 0.8705, g_loss: 2.0313, D(x): 0.68, D(G(z)): 0.23
# Epoch [99/300], Step [600/600], d_loss: 0.7046, g_loss: 1.7627, D(x): 0.75, D(G(z)): 0.22
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.8442, g_loss: 2.1226, D(x): 0.73, D(G(z)): 0.27
# Epoch [100/300], Step [400/600], d_loss: 0.6781, g_loss: 1.9269, D(x): 0.76, D(G(z)): 0.22
# Epoch [100/300], Step [600/600], d_loss: 0.7478, g_loss: 1.7374, D(x): 0.84, D(G(z)): 0.36
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.8017, g_loss: 2.0585, D(x): 0.83, D(G(z)): 0.36
# Epoch [101/300], Step [400/600], d_loss: 1.0618, g_loss: 2.0017, D(x): 0.66, D(G(z)): 0.27
# Epoch [101/300], Step [600/600], d_loss: 1.0211, g_loss: 1.3777, D(x): 0.73, D(G(z)): 0.36
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 1.1679, g_loss: 1.7973, D(x): 0.65, D(G(z)): 0.33
# Epoch [102/300], Step [400/600], d_loss: 0.6129, g_loss: 2.1329, D(x): 0.81, D(G(z)): 0.23
# Epoch [102/300], Step [600/600], d_loss: 0.8537, g_loss: 1.7032, D(x): 0.77, D(G(z)): 0.31
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7956, g_loss: 1.9032, D(x): 0.78, D(G(z)): 0.33
# Epoch [103/300], Step [400/600], d_loss: 1.0147, g_loss: 1.8093, D(x): 0.67, D(G(z)): 0.27
# Epoch [103/300], Step [600/600], d_loss: 0.7886, g_loss: 2.1518, D(x): 0.73, D(G(z)): 0.23
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.7751, g_loss: 1.6713, D(x): 0.73, D(G(z)): 0.25
# Epoch [104/300], Step [400/600], d_loss: 0.8114, g_loss: 1.7180, D(x): 0.71, D(G(z)): 0.28
# Epoch [104/300], Step [600/600], d_loss: 0.9697, g_loss: 1.7797, D(x): 0.67, D(G(z)): 0.25
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.8898, g_loss: 1.5272, D(x): 0.77, D(G(z)): 0.35
# Epoch [105/300], Step [400/600], d_loss: 0.7522, g_loss: 1.5745, D(x): 0.83, D(G(z)): 0.32
# Epoch [105/300], Step [600/600], d_loss: 0.7137, g_loss: 1.7703, D(x): 0.72, D(G(z)): 0.21
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.8420, g_loss: 1.5596, D(x): 0.73, D(G(z)): 0.27
# Epoch [106/300], Step [400/600], d_loss: 0.7439, g_loss: 2.1013, D(x): 0.72, D(G(z)): 0.21
# Epoch [106/300], Step [600/600], d_loss: 1.1303, g_loss: 1.5577, D(x): 0.70, D(G(z)): 0.39
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.8612, g_loss: 2.2297, D(x): 0.64, D(G(z)): 0.19
# Epoch [107/300], Step [400/600], d_loss: 0.7761, g_loss: 1.8805, D(x): 0.75, D(G(z)): 0.25
# Epoch [107/300], Step [600/600], d_loss: 0.8609, g_loss: 1.5834, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.6406, g_loss: 2.0781, D(x): 0.78, D(G(z)): 0.22
# Epoch [108/300], Step [400/600], d_loss: 0.6687, g_loss: 1.9093, D(x): 0.86, D(G(z)): 0.31
# Epoch [108/300], Step [600/600], d_loss: 0.6951, g_loss: 1.7242, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 1.0883, g_loss: 1.7156, D(x): 0.61, D(G(z)): 0.26
# Epoch [109/300], Step [400/600], d_loss: 0.7639, g_loss: 2.0470, D(x): 0.76, D(G(z)): 0.26
# Epoch [109/300], Step [600/600], d_loss: 0.9678, g_loss: 1.6994, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.7990, g_loss: 1.5122, D(x): 0.74, D(G(z)): 0.28
# Epoch [110/300], Step [400/600], d_loss: 0.8673, g_loss: 1.6862, D(x): 0.63, D(G(z)): 0.19
# Epoch [110/300], Step [600/600], d_loss: 0.7326, g_loss: 1.5650, D(x): 0.73, D(G(z)): 0.23
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.8686, g_loss: 1.8162, D(x): 0.80, D(G(z)): 0.35
# Epoch [111/300], Step [400/600], d_loss: 0.7017, g_loss: 1.7161, D(x): 0.78, D(G(z)): 0.26
# Epoch [111/300], Step [600/600], d_loss: 0.8939, g_loss: 1.8244, D(x): 0.68, D(G(z)): 0.24
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.8406, g_loss: 1.8349, D(x): 0.69, D(G(z)): 0.26
# Epoch [112/300], Step [400/600], d_loss: 0.7059, g_loss: 2.1473, D(x): 0.78, D(G(z)): 0.26
# Epoch [112/300], Step [600/600], d_loss: 1.2392, g_loss: 1.9164, D(x): 0.60, D(G(z)): 0.26
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.8774, g_loss: 1.6408, D(x): 0.69, D(G(z)): 0.26
# Epoch [113/300], Step [400/600], d_loss: 0.6904, g_loss: 1.3690, D(x): 0.81, D(G(z)): 0.30
# Epoch [113/300], Step [600/600], d_loss: 0.8986, g_loss: 1.8885, D(x): 0.77, D(G(z)): 0.34
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.8821, g_loss: 1.8293, D(x): 0.64, D(G(z)): 0.21
# Epoch [114/300], Step [400/600], d_loss: 0.7930, g_loss: 2.0159, D(x): 0.73, D(G(z)): 0.27
# Epoch [114/300], Step [600/600], d_loss: 0.6185, g_loss: 1.8900, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.7620, g_loss: 1.6630, D(x): 0.76, D(G(z)): 0.25
# Epoch [115/300], Step [400/600], d_loss: 0.8001, g_loss: 1.6315, D(x): 0.78, D(G(z)): 0.30
# Epoch [115/300], Step [600/600], d_loss: 0.8636, g_loss: 1.9973, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.6809, g_loss: 2.0528, D(x): 0.77, D(G(z)): 0.25
# Epoch [116/300], Step [400/600], d_loss: 0.8373, g_loss: 2.2273, D(x): 0.77, D(G(z)): 0.32
# Epoch [116/300], Step [600/600], d_loss: 0.7148, g_loss: 1.7240, D(x): 0.83, D(G(z)): 0.29
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 1.0632, g_loss: 1.9016, D(x): 0.71, D(G(z)): 0.36
# Epoch [117/300], Step [400/600], d_loss: 0.8663, g_loss: 1.6692, D(x): 0.74, D(G(z)): 0.31
# Epoch [117/300], Step [600/600], d_loss: 0.8301, g_loss: 1.5092, D(x): 0.76, D(G(z)): 0.33
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.7604, g_loss: 1.8528, D(x): 0.72, D(G(z)): 0.23
# Epoch [118/300], Step [400/600], d_loss: 1.0400, g_loss: 1.8253, D(x): 0.66, D(G(z)): 0.31
# Epoch [118/300], Step [600/600], d_loss: 0.7721, g_loss: 1.6056, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.8738, g_loss: 2.6845, D(x): 0.65, D(G(z)): 0.19
# Epoch [119/300], Step [400/600], d_loss: 0.8731, g_loss: 1.7251, D(x): 0.75, D(G(z)): 0.34
# Epoch [119/300], Step [600/600], d_loss: 1.0312, g_loss: 1.8034, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.8164, g_loss: 2.4932, D(x): 0.74, D(G(z)): 0.26
# Epoch [120/300], Step [400/600], d_loss: 0.9022, g_loss: 1.6866, D(x): 0.69, D(G(z)): 0.26
# Epoch [120/300], Step [600/600], d_loss: 0.8505, g_loss: 1.9729, D(x): 0.76, D(G(z)): 0.30
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.9733, g_loss: 1.5002, D(x): 0.67, D(G(z)): 0.27
# Epoch [121/300], Step [400/600], d_loss: 0.8036, g_loss: 1.4110, D(x): 0.76, D(G(z)): 0.29
# Epoch [121/300], Step [600/600], d_loss: 0.7674, g_loss: 2.0308, D(x): 0.81, D(G(z)): 0.31
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8927, g_loss: 1.8735, D(x): 0.74, D(G(z)): 0.32
# Epoch [122/300], Step [400/600], d_loss: 0.9117, g_loss: 2.2631, D(x): 0.65, D(G(z)): 0.24
# Epoch [122/300], Step [600/600], d_loss: 0.8097, g_loss: 1.9213, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.8376, g_loss: 1.2850, D(x): 0.80, D(G(z)): 0.35
# Epoch [123/300], Step [400/600], d_loss: 0.8637, g_loss: 1.8874, D(x): 0.75, D(G(z)): 0.33
# Epoch [123/300], Step [600/600], d_loss: 0.8753, g_loss: 1.6049, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.7985, g_loss: 1.7253, D(x): 0.72, D(G(z)): 0.22
# Epoch [124/300], Step [400/600], d_loss: 1.0305, g_loss: 1.7516, D(x): 0.66, D(G(z)): 0.30
# Epoch [124/300], Step [600/600], d_loss: 0.7578, g_loss: 1.2652, D(x): 0.80, D(G(z)): 0.34
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.7930, g_loss: 1.8669, D(x): 0.74, D(G(z)): 0.28
# Epoch [125/300], Step [400/600], d_loss: 0.7370, g_loss: 2.2116, D(x): 0.70, D(G(z)): 0.23
# Epoch [125/300], Step [600/600], d_loss: 0.7587, g_loss: 2.0367, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.9033, g_loss: 2.2699, D(x): 0.69, D(G(z)): 0.25
# Epoch [126/300], Step [400/600], d_loss: 0.9707, g_loss: 1.3582, D(x): 0.69, D(G(z)): 0.32
# Epoch [126/300], Step [600/600], d_loss: 0.8111, g_loss: 1.8304, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.7493, g_loss: 1.8212, D(x): 0.73, D(G(z)): 0.23
# Epoch [127/300], Step [400/600], d_loss: 1.0511, g_loss: 1.6982, D(x): 0.67, D(G(z)): 0.35
# Epoch [127/300], Step [600/600], d_loss: 0.8185, g_loss: 1.5152, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 1.1070, g_loss: 1.3173, D(x): 0.65, D(G(z)): 0.31
# Epoch [128/300], Step [400/600], d_loss: 1.0079, g_loss: 1.7482, D(x): 0.68, D(G(z)): 0.28
# Epoch [128/300], Step [600/600], d_loss: 0.9745, g_loss: 1.2669, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.8729, g_loss: 1.4355, D(x): 0.75, D(G(z)): 0.32
# Epoch [129/300], Step [400/600], d_loss: 0.7919, g_loss: 1.6927, D(x): 0.69, D(G(z)): 0.21
# Epoch [129/300], Step [600/600], d_loss: 1.1208, g_loss: 1.2440, D(x): 0.70, D(G(z)): 0.39
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.7380, g_loss: 1.5479, D(x): 0.73, D(G(z)): 0.26
# Epoch [130/300], Step [400/600], d_loss: 0.7006, g_loss: 2.3603, D(x): 0.78, D(G(z)): 0.26
# Epoch [130/300], Step [600/600], d_loss: 0.8303, g_loss: 1.1729, D(x): 0.77, D(G(z)): 0.33
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.6615, g_loss: 1.9534, D(x): 0.77, D(G(z)): 0.23
# Epoch [131/300], Step [400/600], d_loss: 1.0240, g_loss: 1.1961, D(x): 0.73, D(G(z)): 0.38
# Epoch [131/300], Step [600/600], d_loss: 0.9381, g_loss: 1.5053, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.9319, g_loss: 1.5828, D(x): 0.76, D(G(z)): 0.35
# Epoch [132/300], Step [400/600], d_loss: 0.9545, g_loss: 1.4935, D(x): 0.66, D(G(z)): 0.24
# Epoch [132/300], Step [600/600], d_loss: 0.8149, g_loss: 1.9505, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.8428, g_loss: 2.0145, D(x): 0.62, D(G(z)): 0.14
# Epoch [133/300], Step [400/600], d_loss: 0.7492, g_loss: 1.7860, D(x): 0.75, D(G(z)): 0.24
# Epoch [133/300], Step [600/600], d_loss: 0.8184, g_loss: 1.2114, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.7129, g_loss: 1.9738, D(x): 0.77, D(G(z)): 0.26
# Epoch [134/300], Step [400/600], d_loss: 0.8982, g_loss: 1.4657, D(x): 0.72, D(G(z)): 0.32
# Epoch [134/300], Step [600/600], d_loss: 0.7586, g_loss: 1.9833, D(x): 0.67, D(G(z)): 0.20
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.9335, g_loss: 1.4501, D(x): 0.65, D(G(z)): 0.25
# Epoch [135/300], Step [400/600], d_loss: 0.9509, g_loss: 1.8040, D(x): 0.76, D(G(z)): 0.40
# Epoch [135/300], Step [600/600], d_loss: 0.9171, g_loss: 1.7135, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 1.1039, g_loss: 2.0857, D(x): 0.61, D(G(z)): 0.23
# Epoch [136/300], Step [400/600], d_loss: 0.8994, g_loss: 1.3997, D(x): 0.76, D(G(z)): 0.35
# Epoch [136/300], Step [600/600], d_loss: 0.8387, g_loss: 1.7704, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.9180, g_loss: 1.8510, D(x): 0.64, D(G(z)): 0.23
# Epoch [137/300], Step [400/600], d_loss: 0.7695, g_loss: 2.1871, D(x): 0.70, D(G(z)): 0.22
# Epoch [137/300], Step [600/600], d_loss: 0.9339, g_loss: 1.6543, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 1.0518, g_loss: 1.5594, D(x): 0.69, D(G(z)): 0.34
# Epoch [138/300], Step [400/600], d_loss: 0.7696, g_loss: 1.9311, D(x): 0.74, D(G(z)): 0.27
# Epoch [138/300], Step [600/600], d_loss: 0.8601, g_loss: 1.6753, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 1.0571, g_loss: 1.3730, D(x): 0.67, D(G(z)): 0.33
# Epoch [139/300], Step [400/600], d_loss: 0.8961, g_loss: 1.6901, D(x): 0.70, D(G(z)): 0.29
# Epoch [139/300], Step [600/600], d_loss: 0.9144, g_loss: 1.6422, D(x): 0.77, D(G(z)): 0.36
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.7691, g_loss: 1.5991, D(x): 0.75, D(G(z)): 0.27
# Epoch [140/300], Step [400/600], d_loss: 1.0229, g_loss: 1.6445, D(x): 0.70, D(G(z)): 0.35
# Epoch [140/300], Step [600/600], d_loss: 0.9174, g_loss: 2.2716, D(x): 0.68, D(G(z)): 0.24
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.8545, g_loss: 1.5979, D(x): 0.71, D(G(z)): 0.26
# Epoch [141/300], Step [400/600], d_loss: 1.2093, g_loss: 1.8534, D(x): 0.57, D(G(z)): 0.26
# Epoch [141/300], Step [600/600], d_loss: 0.8697, g_loss: 1.7190, D(x): 0.78, D(G(z)): 0.32
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.9485, g_loss: 1.3699, D(x): 0.83, D(G(z)): 0.45
# Epoch [142/300], Step [400/600], d_loss: 0.8995, g_loss: 1.4236, D(x): 0.77, D(G(z)): 0.39
# Epoch [142/300], Step [600/600], d_loss: 0.7653, g_loss: 1.2361, D(x): 0.74, D(G(z)): 0.26
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.8156, g_loss: 1.6693, D(x): 0.68, D(G(z)): 0.25
# Epoch [143/300], Step [400/600], d_loss: 0.8876, g_loss: 1.4377, D(x): 0.71, D(G(z)): 0.29
# Epoch [143/300], Step [600/600], d_loss: 0.9965, g_loss: 1.2209, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.9076, g_loss: 1.7305, D(x): 0.68, D(G(z)): 0.28
# Epoch [144/300], Step [400/600], d_loss: 0.9328, g_loss: 1.5462, D(x): 0.67, D(G(z)): 0.27
# Epoch [144/300], Step [600/600], d_loss: 1.0774, g_loss: 1.2626, D(x): 0.73, D(G(z)): 0.43
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9735, g_loss: 1.2151, D(x): 0.70, D(G(z)): 0.32
# Epoch [145/300], Step [400/600], d_loss: 0.9122, g_loss: 1.5226, D(x): 0.70, D(G(z)): 0.30
# Epoch [145/300], Step [600/600], d_loss: 1.1145, g_loss: 1.2841, D(x): 0.64, D(G(z)): 0.34
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.8417, g_loss: 1.7096, D(x): 0.72, D(G(z)): 0.31
# Epoch [146/300], Step [400/600], d_loss: 0.7358, g_loss: 1.7813, D(x): 0.77, D(G(z)): 0.29
# Epoch [146/300], Step [600/600], d_loss: 0.9846, g_loss: 1.6343, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.9673, g_loss: 1.3743, D(x): 0.70, D(G(z)): 0.33
# Epoch [147/300], Step [400/600], d_loss: 1.0796, g_loss: 1.6448, D(x): 0.60, D(G(z)): 0.25
# Epoch [147/300], Step [600/600], d_loss: 0.9780, g_loss: 1.6376, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 1.3539, g_loss: 1.3031, D(x): 0.60, D(G(z)): 0.36
# Epoch [148/300], Step [400/600], d_loss: 0.7599, g_loss: 1.9921, D(x): 0.76, D(G(z)): 0.28
# Epoch [148/300], Step [600/600], d_loss: 1.0533, g_loss: 1.5909, D(x): 0.60, D(G(z)): 0.25
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.9828, g_loss: 1.6792, D(x): 0.63, D(G(z)): 0.25
# Epoch [149/300], Step [400/600], d_loss: 0.8206, g_loss: 1.9162, D(x): 0.76, D(G(z)): 0.33
# Epoch [149/300], Step [600/600], d_loss: 0.9967, g_loss: 1.1605, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.8923, g_loss: 1.5277, D(x): 0.65, D(G(z)): 0.22
# Epoch [150/300], Step [400/600], d_loss: 0.8035, g_loss: 1.9469, D(x): 0.81, D(G(z)): 0.36
# Epoch [150/300], Step [600/600], d_loss: 0.8537, g_loss: 1.4607, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.8419, g_loss: 1.2438, D(x): 0.69, D(G(z)): 0.27
# Epoch [151/300], Step [400/600], d_loss: 0.9117, g_loss: 1.1074, D(x): 0.71, D(G(z)): 0.32
# Epoch [151/300], Step [600/600], d_loss: 0.8847, g_loss: 1.6738, D(x): 0.66, D(G(z)): 0.25
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.8685, g_loss: 1.4992, D(x): 0.72, D(G(z)): 0.32
# Epoch [152/300], Step [400/600], d_loss: 0.7613, g_loss: 2.2155, D(x): 0.74, D(G(z)): 0.28
# Epoch [152/300], Step [600/600], d_loss: 0.9753, g_loss: 1.7906, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.8436, g_loss: 1.3144, D(x): 0.68, D(G(z)): 0.27
# Epoch [153/300], Step [400/600], d_loss: 0.7552, g_loss: 1.7729, D(x): 0.74, D(G(z)): 0.27
# Epoch [153/300], Step [600/600], d_loss: 0.7203, g_loss: 1.5141, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 1.0390, g_loss: 1.5359, D(x): 0.67, D(G(z)): 0.34
# Epoch [154/300], Step [400/600], d_loss: 0.9322, g_loss: 1.5197, D(x): 0.68, D(G(z)): 0.28
# Epoch [154/300], Step [600/600], d_loss: 1.0905, g_loss: 1.3473, D(x): 0.70, D(G(z)): 0.39
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.9017, g_loss: 1.8391, D(x): 0.70, D(G(z)): 0.28
# Epoch [155/300], Step [400/600], d_loss: 1.0333, g_loss: 1.4505, D(x): 0.63, D(G(z)): 0.26
# Epoch [155/300], Step [600/600], d_loss: 0.8586, g_loss: 1.6392, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 1.1205, g_loss: 1.4735, D(x): 0.63, D(G(z)): 0.31
# Epoch [156/300], Step [400/600], d_loss: 0.9767, g_loss: 1.4249, D(x): 0.66, D(G(z)): 0.28
# Epoch [156/300], Step [600/600], d_loss: 1.0068, g_loss: 1.1734, D(x): 0.73, D(G(z)): 0.39
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.7438, g_loss: 1.3758, D(x): 0.76, D(G(z)): 0.29
# Epoch [157/300], Step [400/600], d_loss: 1.0299, g_loss: 1.4711, D(x): 0.63, D(G(z)): 0.27
# Epoch [157/300], Step [600/600], d_loss: 0.7951, g_loss: 1.7689, D(x): 0.68, D(G(z)): 0.20
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.7652, g_loss: 1.4391, D(x): 0.77, D(G(z)): 0.32
# Epoch [158/300], Step [400/600], d_loss: 1.1456, g_loss: 1.3217, D(x): 0.61, D(G(z)): 0.30
# Epoch [158/300], Step [600/600], d_loss: 0.9722, g_loss: 1.6506, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.8945, g_loss: 2.1609, D(x): 0.65, D(G(z)): 0.23
# Epoch [159/300], Step [400/600], d_loss: 0.8938, g_loss: 1.4073, D(x): 0.78, D(G(z)): 0.38
# Epoch [159/300], Step [600/600], d_loss: 0.9507, g_loss: 1.5563, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.9754, g_loss: 1.3076, D(x): 0.69, D(G(z)): 0.33
# ...
# Epoch [247/300], Step [400/600], d_loss: 1.0135, g_loss: 1.2307, D(x): 0.67, D(G(z)): 0.32
# Epoch [247/300], Step [600/600], d_loss: 1.0206, g_loss: 1.5155, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.8145, g_loss: 1.6420, D(x): 0.73, D(G(z)): 0.30
# Epoch [248/300], Step [400/600], d_loss: 0.9694, g_loss: 1.3833, D(x): 0.71, D(G(z)): 0.34
# Epoch [248/300], Step [600/600], d_loss: 1.0266, g_loss: 1.2408, D(x): 0.75, D(G(z)): 0.42
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.9352, g_loss: 1.5244, D(x): 0.67, D(G(z)): 0.28
# Epoch [249/300], Step [400/600], d_loss: 1.1295, g_loss: 1.5653, D(x): 0.65, D(G(z)): 0.33
# Epoch [249/300], Step [600/600], d_loss: 0.9016, g_loss: 1.4725, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 1.0838, g_loss: 1.1926, D(x): 0.65, D(G(z)): 0.34
# Epoch [250/300], Step [400/600], d_loss: 1.1146, g_loss: 1.4464, D(x): 0.67, D(G(z)): 0.41
# Epoch [250/300], Step [600/600], d_loss: 0.9349, g_loss: 1.2741, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.8942, g_loss: 1.5082, D(x): 0.68, D(G(z)): 0.29
# Epoch [251/300], Step [400/600], d_loss: 0.9513, g_loss: 1.4678, D(x): 0.73, D(G(z)): 0.36
# Epoch [251/300], Step [600/600], d_loss: 1.0592, g_loss: 1.2038, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.8858, g_loss: 1.4713, D(x): 0.73, D(G(z)): 0.33
# Epoch [252/300], Step [400/600], d_loss: 1.0716, g_loss: 1.3660, D(x): 0.66, D(G(z)): 0.36
# Epoch [252/300], Step [600/600], d_loss: 0.8353, g_loss: 1.3915, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.9518, g_loss: 1.4099, D(x): 0.76, D(G(z)): 0.40
# Epoch [253/300], Step [400/600], d_loss: 0.9464, g_loss: 1.4652, D(x): 0.61, D(G(z)): 0.23
# Epoch [253/300], Step [600/600], d_loss: 1.0129, g_loss: 1.6468, D(x): 0.58, D(G(z)): 0.23
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.9553, g_loss: 1.4883, D(x): 0.66, D(G(z)): 0.27
# Epoch [254/300], Step [400/600], d_loss: 1.1761, g_loss: 1.6824, D(x): 0.60, D(G(z)): 0.31
# Epoch [254/300], Step [600/600], d_loss: 1.0476, g_loss: 1.6037, D(x): 0.69, D(G(z)): 0.39
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.9413, g_loss: 1.3204, D(x): 0.70, D(G(z)): 0.31
# Epoch [255/300], Step [400/600], d_loss: 1.0428, g_loss: 1.7756, D(x): 0.65, D(G(z)): 0.32
# Epoch [255/300], Step [600/600], d_loss: 1.0319, g_loss: 1.6660, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.9442, g_loss: 1.4025, D(x): 0.76, D(G(z)): 0.38
# Epoch [256/300], Step [400/600], d_loss: 0.8852, g_loss: 1.3673, D(x): 0.72, D(G(z)): 0.30
# Epoch [256/300], Step [600/600], d_loss: 0.8669, g_loss: 1.5074, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 1.0504, g_loss: 1.4607, D(x): 0.67, D(G(z)): 0.37
# Epoch [257/300], Step [400/600], d_loss: 0.9014, g_loss: 1.4539, D(x): 0.66, D(G(z)): 0.26
# Epoch [257/300], Step [600/600], d_loss: 0.9494, g_loss: 1.6451, D(x): 0.64, D(G(z)): 0.27
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 1.0680, g_loss: 1.2165, D(x): 0.63, D(G(z)): 0.32
# Epoch [258/300], Step [400/600], d_loss: 0.8044, g_loss: 1.6554, D(x): 0.71, D(G(z)): 0.28
# Epoch [258/300], Step [600/600], d_loss: 0.9403, g_loss: 1.6066, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.9949, g_loss: 1.6956, D(x): 0.64, D(G(z)): 0.25
# Epoch [259/300], Step [400/600], d_loss: 1.1428, g_loss: 1.6568, D(x): 0.77, D(G(z)): 0.46
# Epoch [259/300], Step [600/600], d_loss: 1.0584, g_loss: 1.5161, D(x): 0.63, D(G(z)): 0.29
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 1.0496, g_loss: 1.3879, D(x): 0.63, D(G(z)): 0.31
# Epoch [260/300], Step [400/600], d_loss: 0.9381, g_loss: 1.4324, D(x): 0.65, D(G(z)): 0.30
# Epoch [260/300], Step [600/600], d_loss: 0.7786, g_loss: 1.4401, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.9650, g_loss: 1.3841, D(x): 0.77, D(G(z)): 0.38
# Epoch [261/300], Step [400/600], d_loss: 0.7692, g_loss: 1.5460, D(x): 0.74, D(G(z)): 0.30
# Epoch [261/300], Step [600/600], d_loss: 0.6833, g_loss: 2.0328, D(x): 0.71, D(G(z)): 0.20
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.9311, g_loss: 1.1565, D(x): 0.74, D(G(z)): 0.38
# Epoch [262/300], Step [400/600], d_loss: 0.7844, g_loss: 1.7003, D(x): 0.75, D(G(z)): 0.29
# Epoch [262/300], Step [600/600], d_loss: 0.8654, g_loss: 1.6416, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 1.0729, g_loss: 1.4231, D(x): 0.66, D(G(z)): 0.33
# Epoch [263/300], Step [400/600], d_loss: 0.9518, g_loss: 1.7485, D(x): 0.67, D(G(z)): 0.30
# Epoch [263/300], Step [600/600], d_loss: 0.9551, g_loss: 1.4389, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 1.0083, g_loss: 1.3022, D(x): 0.67, D(G(z)): 0.33
# Epoch [264/300], Step [400/600], d_loss: 0.8803, g_loss: 1.8448, D(x): 0.67, D(G(z)): 0.26
# Epoch [264/300], Step [600/600], d_loss: 0.8800, g_loss: 1.2871, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.8598, g_loss: 1.8986, D(x): 0.66, D(G(z)): 0.22
# Epoch [265/300], Step [400/600], d_loss: 0.9669, g_loss: 1.3715, D(x): 0.66, D(G(z)): 0.30
# Epoch [265/300], Step [600/600], d_loss: 1.0601, g_loss: 1.3468, D(x): 0.68, D(G(z)): 0.39
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 1.2303, g_loss: 1.4176, D(x): 0.69, D(G(z)): 0.41
# Epoch [266/300], Step [400/600], d_loss: 0.9751, g_loss: 1.2279, D(x): 0.73, D(G(z)): 0.37
# Epoch [266/300], Step [600/600], d_loss: 0.8749, g_loss: 1.8724, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 1.1291, g_loss: 1.1403, D(x): 0.68, D(G(z)): 0.40
# Epoch [267/300], Step [400/600], d_loss: 1.0674, g_loss: 1.5354, D(x): 0.67, D(G(z)): 0.37
# Epoch [267/300], Step [600/600], d_loss: 0.8163, g_loss: 1.3476, D(x): 0.77, D(G(z)): 0.33
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.8372, g_loss: 1.6739, D(x): 0.71, D(G(z)): 0.30
# Epoch [268/300], Step [400/600], d_loss: 0.9719, g_loss: 1.4305, D(x): 0.67, D(G(z)): 0.32
# Epoch [268/300], Step [600/600], d_loss: 1.0145, g_loss: 1.6021, D(x): 0.74, D(G(z)): 0.38
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.8967, g_loss: 1.3910, D(x): 0.68, D(G(z)): 0.28
# Epoch [269/300], Step [400/600], d_loss: 0.9960, g_loss: 1.3173, D(x): 0.66, D(G(z)): 0.31
# Epoch [269/300], Step [600/600], d_loss: 1.0023, g_loss: 1.5595, D(x): 0.61, D(G(z)): 0.25
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9397, g_loss: 1.4169, D(x): 0.67, D(G(z)): 0.29
# Epoch [270/300], Step [400/600], d_loss: 0.9328, g_loss: 1.1860, D(x): 0.77, D(G(z)): 0.38
# Epoch [270/300], Step [600/600], d_loss: 0.8376, g_loss: 1.8074, D(x): 0.69, D(G(z)): 0.25
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.9020, g_loss: 1.5912, D(x): 0.70, D(G(z)): 0.30
# Epoch [271/300], Step [400/600], d_loss: 1.0111, g_loss: 1.7669, D(x): 0.62, D(G(z)): 0.26
# Epoch [271/300], Step [600/600], d_loss: 1.0366, g_loss: 1.3123, D(x): 0.72, D(G(z)): 0.39
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 1.0700, g_loss: 1.2843, D(x): 0.71, D(G(z)): 0.41
# Epoch [272/300], Step [400/600], d_loss: 0.9776, g_loss: 1.6344, D(x): 0.77, D(G(z)): 0.41
# Epoch [272/300], Step [600/600], d_loss: 0.9738, g_loss: 1.7834, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.9838, g_loss: 1.4035, D(x): 0.69, D(G(z)): 0.34
# Epoch [273/300], Step [400/600], d_loss: 0.9249, g_loss: 1.5389, D(x): 0.64, D(G(z)): 0.26
# Epoch [273/300], Step [600/600], d_loss: 1.0071, g_loss: 1.3461, D(x): 0.72, D(G(z)): 0.38
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.8724, g_loss: 1.5587, D(x): 0.77, D(G(z)): 0.35
# Epoch [274/300], Step [400/600], d_loss: 0.9123, g_loss: 1.0923, D(x): 0.68, D(G(z)): 0.29
# Epoch [274/300], Step [600/600], d_loss: 1.0124, g_loss: 1.4106, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.8660, g_loss: 1.4912, D(x): 0.75, D(G(z)): 0.31
# Epoch [275/300], Step [400/600], d_loss: 0.9126, g_loss: 1.3668, D(x): 0.77, D(G(z)): 0.37
# Epoch [275/300], Step [600/600], d_loss: 0.8317, g_loss: 1.3662, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.8124, g_loss: 1.8024, D(x): 0.75, D(G(z)): 0.29
# Epoch [276/300], Step [400/600], d_loss: 0.9566, g_loss: 1.3964, D(x): 0.70, D(G(z)): 0.35
# Epoch [276/300], Step [600/600], d_loss: 0.9377, g_loss: 1.4694, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.9272, g_loss: 1.4387, D(x): 0.74, D(G(z)): 0.35
# Epoch [277/300], Step [400/600], d_loss: 1.0936, g_loss: 1.0475, D(x): 0.69, D(G(z)): 0.41
# Epoch [277/300], Step [600/600], d_loss: 0.7838, g_loss: 1.4217, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.9045, g_loss: 1.4189, D(x): 0.65, D(G(z)): 0.25
# Epoch [278/300], Step [400/600], d_loss: 0.9125, g_loss: 1.4456, D(x): 0.74, D(G(z)): 0.33
# Epoch [278/300], Step [600/600], d_loss: 0.9631, g_loss: 1.3697, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.9198, g_loss: 1.5754, D(x): 0.62, D(G(z)): 0.24
# Epoch [279/300], Step [400/600], d_loss: 0.9858, g_loss: 1.1465, D(x): 0.65, D(G(z)): 0.31
# Epoch [279/300], Step [600/600], d_loss: 0.7868, g_loss: 1.8165, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.8743, g_loss: 1.4419, D(x): 0.72, D(G(z)): 0.30
# Epoch [280/300], Step [400/600], d_loss: 1.0881, g_loss: 1.7303, D(x): 0.56, D(G(z)): 0.23
# Epoch [280/300], Step [600/600], d_loss: 0.9423, g_loss: 1.4698, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8213, g_loss: 1.4231, D(x): 0.73, D(G(z)): 0.28
# Epoch [281/300], Step [400/600], d_loss: 0.8743, g_loss: 1.8287, D(x): 0.67, D(G(z)): 0.26
# Epoch [281/300], Step [600/600], d_loss: 0.9441, g_loss: 1.3031, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.7294, g_loss: 1.8987, D(x): 0.73, D(G(z)): 0.26
# Epoch [282/300], Step [400/600], d_loss: 0.9478, g_loss: 1.4374, D(x): 0.77, D(G(z)): 0.39
# Epoch [282/300], Step [600/600], d_loss: 0.8975, g_loss: 1.3068, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.9485, g_loss: 1.4233, D(x): 0.70, D(G(z)): 0.31
# Epoch [283/300], Step [400/600], d_loss: 0.9945, g_loss: 1.3404, D(x): 0.70, D(G(z)): 0.34
# Epoch [283/300], Step [600/600], d_loss: 0.8772, g_loss: 1.5590, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.9979, g_loss: 1.6102, D(x): 0.68, D(G(z)): 0.32
# Epoch [284/300], Step [400/600], d_loss: 0.9891, g_loss: 1.7431, D(x): 0.72, D(G(z)): 0.35
# Epoch [284/300], Step [600/600], d_loss: 0.9937, g_loss: 1.5971, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.9294, g_loss: 1.7494, D(x): 0.70, D(G(z)): 0.33
# Epoch [285/300], Step [400/600], d_loss: 0.8946, g_loss: 1.6936, D(x): 0.75, D(G(z)): 0.35
# Epoch [285/300], Step [600/600], d_loss: 0.9251, g_loss: 1.4582, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 1.0370, g_loss: 1.4246, D(x): 0.70, D(G(z)): 0.37
# Epoch [286/300], Step [400/600], d_loss: 0.9373, g_loss: 1.1791, D(x): 0.79, D(G(z)): 0.41
# Epoch [286/300], Step [600/600], d_loss: 1.0566, g_loss: 1.4863, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 1.0884, g_loss: 1.4860, D(x): 0.60, D(G(z)): 0.31
# Epoch [287/300], Step [400/600], d_loss: 0.8999, g_loss: 1.5848, D(x): 0.73, D(G(z)): 0.33
# Epoch [287/300], Step [600/600], d_loss: 0.9635, g_loss: 1.5946, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.8281, g_loss: 1.3620, D(x): 0.74, D(G(z)): 0.31
# Epoch [288/300], Step [400/600], d_loss: 0.8703, g_loss: 1.4100, D(x): 0.69, D(G(z)): 0.29
# Epoch [288/300], Step [600/600], d_loss: 1.0818, g_loss: 1.6184, D(x): 0.74, D(G(z)): 0.41
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.7757, g_loss: 1.7035, D(x): 0.70, D(G(z)): 0.24
# Epoch [289/300], Step [400/600], d_loss: 0.8625, g_loss: 1.4696, D(x): 0.67, D(G(z)): 0.26
# Epoch [289/300], Step [600/600], d_loss: 0.9924, g_loss: 1.2968, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.9795, g_loss: 1.5412, D(x): 0.63, D(G(z)): 0.31
# Epoch [290/300], Step [400/600], d_loss: 1.0798, g_loss: 1.5311, D(x): 0.58, D(G(z)): 0.27
# Epoch [290/300], Step [600/600], d_loss: 1.1215, g_loss: 1.2614, D(x): 0.62, D(G(z)): 0.33
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 1.0035, g_loss: 1.4840, D(x): 0.70, D(G(z)): 0.34
# Epoch [291/300], Step [400/600], d_loss: 0.9056, g_loss: 1.6933, D(x): 0.64, D(G(z)): 0.23
# Epoch [291/300], Step [600/600], d_loss: 0.8747, g_loss: 1.5985, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.8537, g_loss: 1.6136, D(x): 0.71, D(G(z)): 0.29
# Epoch [292/300], Step [400/600], d_loss: 0.9614, g_loss: 1.4903, D(x): 0.67, D(G(z)): 0.32
# Epoch [292/300], Step [600/600], d_loss: 0.8666, g_loss: 1.4415, D(x): 0.77, D(G(z)): 0.33
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.9954, g_loss: 1.7423, D(x): 0.66, D(G(z)): 0.28
# Epoch [293/300], Step [400/600], d_loss: 1.0117, g_loss: 1.7331, D(x): 0.66, D(G(z)): 0.31
# Epoch [293/300], Step [600/600], d_loss: 1.0077, g_loss: 1.5258, D(x): 0.70, D(G(z)): 0.36
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.8780, g_loss: 1.7607, D(x): 0.69, D(G(z)): 0.24
# Epoch [294/300], Step [400/600], d_loss: 0.7909, g_loss: 1.7737, D(x): 0.74, D(G(z)): 0.28
# Epoch [294/300], Step [600/600], d_loss: 0.9688, g_loss: 1.4940, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.9545, g_loss: 1.4760, D(x): 0.69, D(G(z)): 0.33
# Epoch [295/300], Step [400/600], d_loss: 0.8570, g_loss: 1.3298, D(x): 0.69, D(G(z)): 0.30
# Epoch [295/300], Step [600/600], d_loss: 0.8913, g_loss: 1.3745, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9683, g_loss: 1.2727, D(x): 0.77, D(G(z)): 0.39
# Epoch [296/300], Step [400/600], d_loss: 0.9288, g_loss: 1.5263, D(x): 0.73, D(G(z)): 0.35
# Epoch [296/300], Step [600/600], d_loss: 0.7909, g_loss: 1.6490, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.9331, g_loss: 1.5712, D(x): 0.71, D(G(z)): 0.34
# Epoch [297/300], Step [400/600], d_loss: 1.1522, g_loss: 1.6156, D(x): 0.67, D(G(z)): 0.39
# Epoch [297/300], Step [600/600], d_loss: 0.9601, g_loss: 1.2991, D(x): 0.74, D(G(z)): 0.37
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.9055, g_loss: 1.5266, D(x): 0.70, D(G(z)): 0.31
# Epoch [298/300], Step [400/600], d_loss: 0.9985, g_loss: 1.3287, D(x): 0.74, D(G(z)): 0.37
# Epoch [298/300], Step [600/600], d_loss: 0.9747, g_loss: 1.6441, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.8361, g_loss: 1.6011, D(x): 0.72, D(G(z)): 0.27
# Epoch [299/300], Step [400/600], d_loss: 0.9254, g_loss: 1.5935, D(x): 0.70, D(G(z)): 0.34
# Epoch [299/300], Step [600/600], d_loss: 0.8610, g_loss: 1.7419, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0300.png
# CPU times: user 1h 24min 3s, sys: 34 s, total: 1h 24min 37s
# Wall time: 1h 24min 56s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.mp4'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# ## Save and Commit
#
# We can caputre a snapshot of our work (including the Jupyter notebook, sample images and trained models) using the `jovian` Python library.

# %%
# Install the library
# !pip install jovian --upgrade -q
# Out:
#      |████████████████████████████████| 71kB 2.0MB/s
#   Building wheel for uuid (setup.py) ... done

# %%
# Import the library
import jovian

# %%
jovian.commit(outputs=['samples/fake_images-0000.png', 
                       'samples/fake_images-0010.png', 
                       'samples/fake_images-0025.png', 
                       'samples/fake_images-0050.png', 
                       'samples/fake_images-0100.png', 
                       'samples/fake_images-0150.png', 
                       'samples/fake_images-0200.png', 
                       'samples/fake_images-0250.png', 
                       'samples/fake_images-0300.png', 
                       'gans_training.avi'], 
              project='06-mnist-gan')
# Out:
# [jovian] Error: Failed to detect Jupyter notebook or Python script. Skipping..

# %% [markdown]
# Running `jovian.commit` uploads the Jupyter notebook and the associated files to your [Jovian.ml](https://www.jovian.ml) account. You can share the project online publicly, or collaborate privately with your friends & colleagues. Jovian also automatically captures the Python environment (dependencies & library versions), so that you & others can reproduce your work easily. Jovian also includes a powerful commenting interface for discussion. To learn more visit [www.jovian.ml](https://www.jovian.ml).
#
# <img src="https://i.imgur.com/KVjXpd6.png">

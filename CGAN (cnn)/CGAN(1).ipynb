# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models
# * Commit to Jovian.ml

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST
import numpy as np
from torch import  nn



mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)

img.shape
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# torch.Size([1, 28, 28])

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):

    out = (x + 1) / 2


    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)

plt.figure()

plt.imshow(img[0],cmap = 'gray')
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([1, 9, 4, 0, 6, 1, 7, 8, 4, 9, 1, 5, 7, 4, 0, 1, 7, 9, 6, 5, 0, 7, 9, 2,
#         7, 4, 1, 4, 3, 6, 6, 2, 0, 4, 4, 0, 5, 1, 4, 9, 0, 3, 1, 6, 4, 0, 2, 2,
#         9, 1, 0, 3, 7, 1, 1, 2, 1, 5, 3, 7, 1, 3, 2, 8, 7, 7, 9, 9, 5, 8, 3, 7,
#         8, 7, 9, 5, 6, 3, 2, 7, 1, 7, 3, 6, 7, 9, 2, 7, 9, 4, 2, 0, 2, 0, 1, 7,
#         0, 8, 5, 0])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
n_classes = 10
image_size = 784
hidden_size = 256

latent_size = 64

batch_size  = 100

# %% [markdown]
# ## Discriminator Network

# %% [markdown]
# DCGAN

# %%
n_channels = 1

img_size = 28

def discriminator_block(in_filters, out_filters, bn=True):
    block = [nn.Conv2d(in_filters, out_filters, 3, 2, 1), nn.LeakyReLU(0.2, inplace=True), nn.Dropout2d(0.25)]
    if bn:
        block.append(nn.BatchNorm2d(out_filters, 0.8))
    return block


class Discriminator_DCGAN(nn.Module):

  def __init__(self):

    super(Discriminator_DCGAN,self).__init__()


    d_size = round(img_size/2**3)


    self.label_encoder = nn.Embedding(n_classes,img_size ** 2)

    self.model = nn.Sequential(
                        *discriminator_block(2,64,bn = False),
                        *discriminator_block(64,128),
                        *discriminator_block(128,32),
                        )

    self.avg_layer = nn.Linear(32 * 4 * 4 , 1)


  def forward(self,image,labels):

        labels = self.label_encoder(labels)
        labels = labels.view(labels.shape[0], 1, img_size, img_size)

        input = torch.cat((image,labels),1)

        
        out = self.model(input)

        out = out.view(image.shape[0],-1)

        out = self.avg_layer(out)


        return torch.sigmoid(out)

# D2.to(device);

# %%
# D2(torch.rand(32,1,28,28))

Discriminator_DCGAN().forward(torch.rand(2,1,28,28),torch.LongTensor([1,1])).shape
# Out:
# torch.Size([2, 1])

# %% [markdown]
# ## Generator Network

# %% [markdown]
# DCGAN

# %%
class Generator_DCGAN(nn.Module):
    def __init__(self):
        super(Generator_DCGAN, self).__init__()

        
        self.init_size = 28 // 4

        output = 64 * self.init_size ** 2

        self.label_encoder = nn.Embedding(n_classes,output)


        self.l1 = nn.Linear(64,output)


        self.conv_blocks = nn.Sequential(
            nn.BatchNorm2d(128), # 32 , 128 , 7, 7 
            nn.Upsample(scale_factor=2), # 32,128,14,14
            nn.Conv2d(128, 128, 3, stride=1, padding=1),
            nn.BatchNorm2d(128, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Upsample(scale_factor=2),#32,128,28,28
            nn.Conv2d(128, 64, 3, stride=1, padding=1),
            nn.BatchNorm2d(64, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 1, 3, stride=1, padding=1), # 32,1,28,28
            nn.Tanh(),
        )

    def forward(self,noise,labels):
        noise = self.l1(noise)
        noise = noise.view(noise.shape[0], 64, self.init_size, self.init_size)

        labels = self.label_encoder(labels)
        labels = labels.view(labels.shape[0], 64, self.init_size, self.init_size)

        input = torch.cat((noise,labels),1)

        
        img = self.conv_blocks(input)
        return img

# %%
Generator_DCGAN().forward(torch.rand(2,64),torch.LongTensor([1,2])).shape
# Out:
# torch.Size([2, 128, 7, 7])
# torch.Size([2, 1, 28, 28])

# %%
G = Generator_DCGAN()
D = Discriminator_DCGAN()

#loss function

criterion = nn.BCELoss()

# criterion = nn.MSELoss()

D.to(device)
G.to(device)

d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images,labels):


    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images,labels)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    gen_labels = torch.LongTensor(np.random.randint(0, n_classes, batch_size)).to(device)

    fake_images = G(z,gen_labels)
    outputs = D(fake_images,gen_labels)

    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %%
def train_generator():
    '''
    by setting the labels to 1 the initial loss will be hight 
    as the optimizer (adam ) will try to reduce it. 

    '''
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    gen_labels = torch.LongTensor(np.random.randint(0, n_classes, batch_size)).to(device)
    fake_images = G(z,gen_labels)

    labels = torch.ones(batch_size, 1).to(device)

    g_loss = criterion(D(fake_images,gen_labels), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## EDA
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples_cdcgan'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
# torch.save(G.state_dict(),'G_CGAN_epochs_0.pt')

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)
sample_labels = torch.LongTensor(np.random.randint(0,10,batch_size)).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors,sample_labels)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %% [markdown]
# # Training Method

# %%
# %%time

num_epochs = 100
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images,labels) in enumerate(data_loader):
        # Load a batch & transform to vectors
        
        # print(images.shape)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images.to(device),labels.to(device))
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/100], Step [200/600], d_loss: 1.1142, g_loss: 0.7055, D(x): 0.71, D(G(z)): 0.50
# Epoch [0/100], Step [400/600], d_loss: 0.8962, g_loss: 1.0452, D(x): 0.68, D(G(z)): 0.39
# Epoch [0/100], Step [600/600], d_loss: 1.1626, g_loss: 1.0589, D(x): 0.56, D(G(z)): 0.40
# Saving fake_images-0001.png
# Epoch [1/100], Step [200/600], d_loss: 1.3225, g_loss: 0.8441, D(x): 0.60, D(G(z)): 0.50
# Epoch [1/100], Step [400/600], d_loss: 1.2634, g_loss: 0.9809, D(x): 0.51, D(G(z)): 0.40
# Epoch [1/100], Step [600/600], d_loss: 1.4354, g_loss: 0.7851, D(x): 0.50, D(G(z)): 0.49
# Saving fake_images-0002.png
# Epoch [2/100], Step [200/600], d_loss: 1.2439, g_loss: 0.8911, D(x): 0.53, D(G(z)): 0.42
# Epoch [2/100], Step [400/600], d_loss: 1.1655, g_loss: 1.0239, D(x): 0.59, D(G(z)): 0.43
# Epoch [2/100], Step [600/600], d_loss: 1.2002, g_loss: 1.0441, D(x): 0.52, D(G(z)): 0.38
# Saving fake_images-0003.png
# Epoch [3/100], Step [200/600], d_loss: 1.0612, g_loss: 0.9245, D(x): 0.72, D(G(z)): 0.48
# Epoch [3/100], Step [400/600], d_loss: 1.0739, g_loss: 1.0998, D(x): 0.59, D(G(z)): 0.37
# Epoch [3/100], Step [600/600], d_loss: 1.0071, g_loss: 0.8517, D(x): 0.70, D(G(z)): 0.44
# Saving fake_images-0004.png
# Epoch [4/100], Step [200/600], d_loss: 1.1005, g_loss: 1.0875, D(x): 0.57, D(G(z)): 0.36
# Epoch [4/100], Step [400/600], d_loss: 1.3389, g_loss: 1.0574, D(x): 0.51, D(G(z)): 0.43
# Epoch [4/100], Step [600/600], d_loss: 1.2099, g_loss: 0.8098, D(x): 0.64, D(G(z)): 0.49
# Saving fake_images-0005.png
# Epoch [5/100], Step [200/600], d_loss: 1.2076, g_loss: 0.8921, D(x): 0.55, D(G(z)): 0.41
# Epoch [5/100], Step [400/600], d_loss: 1.1295, g_loss: 0.9626, D(x): 0.61, D(G(z)): 0.43
# Epoch [5/100], Step [600/600], d_loss: 1.4055, g_loss: 1.0234, D(x): 0.46, D(G(z)): 0.40
# Saving fake_images-0006.png
# Epoch [6/100], Step [200/600], d_loss: 1.1042, g_loss: 0.9381, D(x): 0.64, D(G(z)): 0.42
# Epoch [6/100], Step [400/600], d_loss: 1.0378, g_loss: 0.9704, D(x): 0.64, D(G(z)): 0.40
# Epoch [6/100], Step [600/600], d_loss: 1.2088, g_loss: 1.0950, D(x): 0.61, D(G(z)): 0.42
# Saving fake_images-0007.png
# Epoch [7/100], Step [200/600], d_loss: 1.1188, g_loss: 1.2173, D(x): 0.61, D(G(z)): 0.41
# Epoch [7/100], Step [400/600], d_loss: 1.1164, g_loss: 1.2324, D(x): 0.61, D(G(z)): 0.40
# Epoch [7/100], Step [600/600], d_loss: 1.1561, g_loss: 1.0662, D(x): 0.59, D(G(z)): 0.38
# Saving fake_images-0008.png
# Epoch [8/100], Step [200/600], d_loss: 1.1802, g_loss: 1.0359, D(x): 0.61, D(G(z)): 0.41
# Epoch [8/100], Step [400/600], d_loss: 1.1816, g_loss: 1.0003, D(x): 0.59, D(G(z)): 0.39
# Epoch [8/100], Step [600/600], d_loss: 1.1764, g_loss: 1.0724, D(x): 0.58, D(G(z)): 0.39
# Saving fake_images-0009.png
# Epoch [9/100], Step [200/600], d_loss: 1.3285, g_loss: 1.0283, D(x): 0.58, D(G(z)): 0.48
# Epoch [9/100], Step [400/600], d_loss: 1.1674, g_loss: 1.1315, D(x): 0.58, D(G(z)): 0.39
# Epoch [9/100], Step [600/600], d_loss: 1.0049, g_loss: 1.3331, D(x): 0.63, D(G(z)): 0.34
# Saving fake_images-0010.png
# Epoch [10/100], Step [200/600], d_loss: 1.1167, g_loss: 0.9810, D(x): 0.57, D(G(z)): 0.36
# Epoch [10/100], Step [400/600], d_loss: 1.3197, g_loss: 0.8010, D(x): 0.56, D(G(z)): 0.45
# Epoch [10/100], Step [600/600], d_loss: 1.5285, g_loss: 1.1858, D(x): 0.56, D(G(z)): 0.55
# Saving fake_images-0011.png
# Epoch [11/100], Step [200/600], d_loss: 1.1427, g_loss: 1.1191, D(x): 0.66, D(G(z)): 0.47
# Epoch [11/100], Step [400/600], d_loss: 1.1539, g_loss: 0.8836, D(x): 0.58, D(G(z)): 0.40
# Epoch [11/100], Step [600/600], d_loss: 1.2476, g_loss: 0.8689, D(x): 0.60, D(G(z)): 0.47
# Saving fake_images-0012.png
# Epoch [12/100], Step [200/600], d_loss: 1.0737, g_loss: 1.1314, D(x): 0.62, D(G(z)): 0.40
# Epoch [12/100], Step [400/600], d_loss: 1.4191, g_loss: 0.8610, D(x): 0.50, D(G(z)): 0.45
# Epoch [12/100], Step [600/600], d_loss: 1.1316, g_loss: 0.9546, D(x): 0.69, D(G(z)): 0.49
# Saving fake_images-0013.png
# Epoch [13/100], Step [200/600], d_loss: 1.1490, g_loss: 1.1299, D(x): 0.64, D(G(z)): 0.46
# Epoch [13/100], Step [400/600], d_loss: 1.2606, g_loss: 1.0726, D(x): 0.59, D(G(z)): 0.47
# Epoch [13/100], Step [600/600], d_loss: 1.3086, g_loss: 0.9035, D(x): 0.62, D(G(z)): 0.52
# Saving fake_images-0014.png
# Epoch [14/100], Step [200/600], d_loss: 1.1014, g_loss: 0.9410, D(x): 0.68, D(G(z)): 0.46
# Epoch [14/100], Step [400/600], d_loss: 1.4016, g_loss: 0.8063, D(x): 0.50, D(G(z)): 0.47
# Epoch [14/100], Step [600/600], d_loss: 1.3158, g_loss: 0.7187, D(x): 0.50, D(G(z)): 0.41
# Saving fake_images-0015.png
# Epoch [15/100], Step [200/600], d_loss: 1.5050, g_loss: 1.1387, D(x): 0.59, D(G(z)): 0.59
# Epoch [15/100], Step [400/600], d_loss: 1.6536, g_loss: 0.7981, D(x): 0.41, D(G(z)): 0.47
# Epoch [15/100], Step [600/600], d_loss: 1.3911, g_loss: 1.0140, D(x): 0.44, D(G(z)): 0.39
# Saving fake_images-0016.png
# Epoch [16/100], Step [200/600], d_loss: 1.2545, g_loss: 0.8742, D(x): 0.55, D(G(z)): 0.45
# Epoch [16/100], Step [400/600], d_loss: 1.4158, g_loss: 0.5772, D(x): 0.64, D(G(z)): 0.59
# Epoch [16/100], Step [600/600], d_loss: 1.6370, g_loss: 0.8968, D(x): 0.44, D(G(z)): 0.51
# Saving fake_images-0017.png
# Epoch [17/100], Step [200/600], d_loss: 1.7380, g_loss: 0.6628, D(x): 0.54, D(G(z)): 0.64
# Epoch [17/100], Step [400/600], d_loss: 1.4290, g_loss: 0.7136, D(x): 0.53, D(G(z)): 0.52
# Epoch [17/100], Step [600/600], d_loss: 0.9527, g_loss: 0.9538, D(x): 0.68, D(G(z)): 0.40
# Saving fake_images-0018.png
# Epoch [18/100], Step [200/600], d_loss: 1.1214, g_loss: 0.9496, D(x): 0.54, D(G(z)): 0.36
# Epoch [18/100], Step [400/600], d_loss: 1.6570, g_loss: 0.5603, D(x): 0.41, D(G(z)): 0.49
# Epoch [18/100], Step [600/600], d_loss: 1.6080, g_loss: 1.0448, D(x): 0.42, D(G(z)): 0.48
# Saving fake_images-0019.png
# Epoch [19/100], Step [200/600], d_loss: 1.5242, g_loss: 0.7141, D(x): 0.59, D(G(z)): 0.60
# Epoch [19/100], Step [400/600], d_loss: 1.3355, g_loss: 0.4319, D(x): 0.53, D(G(z)): 0.48
# Epoch [19/100], Step [600/600], d_loss: 1.3915, g_loss: 0.6668, D(x): 0.47, D(G(z)): 0.44
# Saving fake_images-0020.png
# Epoch [20/100], Step [200/600], d_loss: 1.3982, g_loss: 0.4585, D(x): 0.63, D(G(z)): 0.59
# Epoch [20/100], Step [400/600], d_loss: 1.0690, g_loss: 1.1083, D(x): 0.56, D(G(z)): 0.36
# Epoch [20/100], Step [600/600], d_loss: 1.5915, g_loss: 0.5176, D(x): 0.53, D(G(z)): 0.58
# Saving fake_images-0021.png
# Epoch [21/100], Step [200/600], d_loss: 1.3836, g_loss: 0.8514, D(x): 0.45, D(G(z)): 0.39
# Epoch [21/100], Step [400/600], d_loss: 0.9910, g_loss: 0.5846, D(x): 0.64, D(G(z)): 0.40
# Epoch [21/100], Step [600/600], d_loss: 0.9527, g_loss: 0.7248, D(x): 0.58, D(G(z)): 0.30
# Saving fake_images-0022.png
# Epoch [22/100], Step [200/600], d_loss: 1.1104, g_loss: 1.5397, D(x): 0.60, D(G(z)): 0.43
# Epoch [22/100], Step [400/600], d_loss: 1.5227, g_loss: 1.0343, D(x): 0.38, D(G(z)): 0.40
# Epoch [22/100], Step [600/600], d_loss: 1.3323, g_loss: 0.3995, D(x): 0.60, D(G(z)): 0.54
# Saving fake_images-0023.png
# Epoch [23/100], Step [200/600], d_loss: 1.2588, g_loss: 1.2427, D(x): 0.67, D(G(z)): 0.56
# Epoch [23/100], Step [400/600], d_loss: 1.1797, g_loss: 0.7191, D(x): 0.53, D(G(z)): 0.40
# Epoch [23/100], Step [600/600], d_loss: 1.5580, g_loss: 0.4368, D(x): 0.59, D(G(z)): 0.63
# Saving fake_images-0024.png
# Epoch [24/100], Step [200/600], d_loss: 0.9182, g_loss: 0.5678, D(x): 0.63, D(G(z)): 0.34
# Epoch [24/100], Step [400/600], d_loss: 1.4157, g_loss: 0.8342, D(x): 0.48, D(G(z)): 0.46
# Epoch [24/100], Step [600/600], d_loss: 1.1547, g_loss: 0.5636, D(x): 0.47, D(G(z)): 0.31
# Saving fake_images-0025.png
# Epoch [25/100], Step [200/600], d_loss: 1.4463, g_loss: 1.0047, D(x): 0.44, D(G(z)): 0.44
# Epoch [25/100], Step [400/600], d_loss: 1.4195, g_loss: 0.9634, D(x): 0.47, D(G(z)): 0.47
# Epoch [25/100], Step [600/600], d_loss: 1.4436, g_loss: 0.9477, D(x): 0.41, D(G(z)): 0.39
# Saving fake_images-0026.png
# Epoch [26/100], Step [200/600], d_loss: 1.2529, g_loss: 1.0976, D(x): 0.51, D(G(z)): 0.42
# Epoch [26/100], Step [400/600], d_loss: 1.2335, g_loss: 1.4407, D(x): 0.58, D(G(z)): 0.47
# Epoch [26/100], Step [600/600], d_loss: 0.7532, g_loss: 0.3861, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0027.png
# Epoch [27/100], Step [200/600], d_loss: 1.4961, g_loss: 0.8310, D(x): 0.48, D(G(z)): 0.52
# Epoch [27/100], Step [400/600], d_loss: 1.2370, g_loss: 0.8476, D(x): 0.50, D(G(z)): 0.41
# Epoch [27/100], Step [600/600], d_loss: 1.2326, g_loss: 0.7887, D(x): 0.60, D(G(z)): 0.50
# Saving fake_images-0028.png
# Epoch [28/100], Step [200/600], d_loss: 1.6346, g_loss: 0.8370, D(x): 0.52, D(G(z)): 0.61
# Epoch [28/100], Step [400/600], d_loss: 1.2846, g_loss: 0.6552, D(x): 0.70, D(G(z)): 0.59
# Epoch [28/100], Step [600/600], d_loss: 1.2515, g_loss: 0.7495, D(x): 0.49, D(G(z)): 0.39
# Saving fake_images-0029.png
# Epoch [29/100], Step [200/600], d_loss: 1.0976, g_loss: 0.8810, D(x): 0.51, D(G(z)): 0.33
# Epoch [29/100], Step [400/600], d_loss: 1.2650, g_loss: 0.4948, D(x): 0.44, D(G(z)): 0.33
# Epoch [29/100], Step [600/600], d_loss: 1.1952, g_loss: 0.4834, D(x): 0.55, D(G(z)): 0.43
# Saving fake_images-0030.png
# Epoch [30/100], Step [200/600], d_loss: 1.3382, g_loss: 0.7543, D(x): 0.56, D(G(z)): 0.51
# Epoch [30/100], Step [400/600], d_loss: 0.9162, g_loss: 0.7172, D(x): 0.62, D(G(z)): 0.34
# Epoch [30/100], Step [600/600], d_loss: 1.6965, g_loss: 0.9019, D(x): 0.50, D(G(z)): 0.62
# Saving fake_images-0031.png
# Epoch [31/100], Step [200/600], d_loss: 1.6070, g_loss: 0.6292, D(x): 0.43, D(G(z)): 0.51
# Epoch [31/100], Step [400/600], d_loss: 1.2183, g_loss: 0.6285, D(x): 0.58, D(G(z)): 0.47
# Epoch [31/100], Step [600/600], d_loss: 0.9093, g_loss: 1.1171, D(x): 0.67, D(G(z)): 0.38
# Saving fake_images-0032.png
# Epoch [32/100], Step [200/600], d_loss: 2.0940, g_loss: 0.5850, D(x): 0.69, D(G(z)): 0.81
# Epoch [32/100], Step [400/600], d_loss: 1.2799, g_loss: 0.4286, D(x): 0.47, D(G(z)): 0.39
# Epoch [32/100], Step [600/600], d_loss: 1.1225, g_loss: 0.7780, D(x): 0.58, D(G(z)): 0.43
# Saving fake_images-0033.png
# Epoch [33/100], Step [200/600], d_loss: 1.0007, g_loss: 0.8157, D(x): 0.53, D(G(z)): 0.29
# Epoch [33/100], Step [400/600], d_loss: 1.1739, g_loss: 0.7345, D(x): 0.55, D(G(z)): 0.42
# Epoch [33/100], Step [600/600], d_loss: 0.9362, g_loss: 0.3916, D(x): 0.66, D(G(z)): 0.39
# Saving fake_images-0034.png
# Epoch [34/100], Step [200/600], d_loss: 1.3058, g_loss: 1.0392, D(x): 0.53, D(G(z)): 0.48
# Epoch [34/100], Step [400/600], d_loss: 1.2049, g_loss: 0.6084, D(x): 0.57, D(G(z)): 0.47
# Epoch [34/100], Step [600/600], d_loss: 1.4173, g_loss: 0.6784, D(x): 0.58, D(G(z)): 0.57
# Saving fake_images-0035.png
# Epoch [35/100], Step [200/600], d_loss: 1.3083, g_loss: 1.2125, D(x): 0.49, D(G(z)): 0.43
# Epoch [35/100], Step [400/600], d_loss: 1.4108, g_loss: 0.7703, D(x): 0.44, D(G(z)): 0.42
# Epoch [35/100], Step [600/600], d_loss: 1.1885, g_loss: 0.9148, D(x): 0.51, D(G(z)): 0.39
# Saving fake_images-0036.png
# Epoch [36/100], Step [200/600], d_loss: 1.1957, g_loss: 0.8853, D(x): 0.53, D(G(z)): 0.41
# Epoch [36/100], Step [400/600], d_loss: 1.5838, g_loss: 1.2057, D(x): 0.49, D(G(z)): 0.57
# Epoch [36/100], Step [600/600], d_loss: 0.9286, g_loss: 0.8776, D(x): 0.59, D(G(z)): 0.32
# Saving fake_images-0037.png
# Epoch [37/100], Step [200/600], d_loss: 1.8889, g_loss: 0.6788, D(x): 0.42, D(G(z)): 0.62
# Epoch [37/100], Step [400/600], d_loss: 0.7553, g_loss: 0.6605, D(x): 0.66, D(G(z)): 0.28
# Epoch [37/100], Step [600/600], d_loss: 0.9274, g_loss: 1.0980, D(x): 0.68, D(G(z)): 0.41
# Saving fake_images-0038.png
# Epoch [38/100], Step [200/600], d_loss: 1.5721, g_loss: 1.5123, D(x): 0.49, D(G(z)): 0.56
# Epoch [38/100], Step [400/600], d_loss: 0.9838, g_loss: 0.7484, D(x): 0.68, D(G(z)): 0.44
# Epoch [38/100], Step [600/600], d_loss: 1.2739, g_loss: 0.5144, D(x): 0.60, D(G(z)): 0.52
# Saving fake_images-0039.png
# Epoch [39/100], Step [200/600], d_loss: 1.2903, g_loss: 0.7196, D(x): 0.66, D(G(z)): 0.57
# Epoch [39/100], Step [400/600], d_loss: 1.3172, g_loss: 0.7587, D(x): 0.49, D(G(z)): 0.43
# Epoch [39/100], Step [600/600], d_loss: 1.5005, g_loss: 0.6094, D(x): 0.52, D(G(z)): 0.56
# Saving fake_images-0040.png
# Epoch [40/100], Step [200/600], d_loss: 1.6616, g_loss: 0.6690, D(x): 0.49, D(G(z)): 0.59
# Epoch [40/100], Step [400/600], d_loss: 0.6701, g_loss: 1.0108, D(x): 0.78, D(G(z)): 0.34
# Epoch [40/100], Step [600/600], d_loss: 1.5200, g_loss: 0.9959, D(x): 0.46, D(G(z)): 0.51
# Saving fake_images-0041.png
# Epoch [41/100], Step [200/600], d_loss: 1.0625, g_loss: 0.7804, D(x): 0.66, D(G(z)): 0.46
# Epoch [41/100], Step [400/600], d_loss: 2.0360, g_loss: 0.8086, D(x): 0.30, D(G(z)): 0.54
# Epoch [41/100], Step [600/600], d_loss: 1.3168, g_loss: 0.9234, D(x): 0.55, D(G(z)): 0.49
# Saving fake_images-0042.png
# Epoch [42/100], Step [200/600], d_loss: 1.1814, g_loss: 0.7065, D(x): 0.55, D(G(z)): 0.43
# Epoch [42/100], Step [400/600], d_loss: 1.1745, g_loss: 0.5478, D(x): 0.48, D(G(z)): 0.34
# Epoch [42/100], Step [600/600], d_loss: 1.1048, g_loss: 0.9499, D(x): 0.52, D(G(z)): 0.35
# Saving fake_images-0043.png
# Epoch [43/100], Step [200/600], d_loss: 1.0758, g_loss: 0.4514, D(x): 0.72, D(G(z)): 0.51
# Epoch [43/100], Step [400/600], d_loss: 1.2545, g_loss: 0.7403, D(x): 0.70, D(G(z)): 0.58
# Epoch [43/100], Step [600/600], d_loss: 1.2894, g_loss: 0.8906, D(x): 0.58, D(G(z)): 0.51
# Saving fake_images-0044.png
# Epoch [44/100], Step [200/600], d_loss: 1.4811, g_loss: 1.2368, D(x): 0.47, D(G(z)): 0.50
# Epoch [44/100], Step [400/600], d_loss: 0.8096, g_loss: 1.0822, D(x): 0.60, D(G(z)): 0.25
# Epoch [44/100], Step [600/600], d_loss: 1.0807, g_loss: 0.5449, D(x): 0.78, D(G(z)): 0.55
# Saving fake_images-0045.png
# Epoch [45/100], Step [200/600], d_loss: 1.7293, g_loss: 0.6100, D(x): 0.48, D(G(z)): 0.61
# Epoch [45/100], Step [400/600], d_loss: 1.2805, g_loss: 1.0865, D(x): 0.53, D(G(z)): 0.46
# Epoch [45/100], Step [600/600], d_loss: 1.5079, g_loss: 0.9013, D(x): 0.38, D(G(z)): 0.39
# Saving fake_images-0046.png
# Epoch [46/100], Step [200/600], d_loss: 1.2222, g_loss: 1.1701, D(x): 0.43, D(G(z)): 0.29
# Epoch [46/100], Step [400/600], d_loss: 1.5910, g_loss: 1.1891, D(x): 0.58, D(G(z)): 0.64
# Epoch [46/100], Step [600/600], d_loss: 1.4478, g_loss: 0.6551, D(x): 0.61, D(G(z)): 0.60
# Saving fake_images-0047.png
# Epoch [47/100], Step [200/600], d_loss: 1.2635, g_loss: 0.9015, D(x): 0.60, D(G(z)): 0.52
# Epoch [47/100], Step [400/600], d_loss: 0.8118, g_loss: 0.9271, D(x): 0.61, D(G(z)): 0.26
# Epoch [47/100], Step [600/600], d_loss: 1.0208, g_loss: 0.8533, D(x): 0.66, D(G(z)): 0.44
# Saving fake_images-0048.png
# Epoch [48/100], Step [200/600], d_loss: 1.0979, g_loss: 1.0275, D(x): 0.52, D(G(z)): 0.35
# Epoch [48/100], Step [400/600], d_loss: 1.3899, g_loss: 0.7753, D(x): 0.37, D(G(z)): 0.32
# Epoch [48/100], Step [600/600], d_loss: 0.8908, g_loss: 0.8407, D(x): 0.62, D(G(z)): 0.33
# Saving fake_images-0049.png
# Epoch [49/100], Step [200/600], d_loss: 1.4126, g_loss: 0.6455, D(x): 0.67, D(G(z)): 0.63
# Epoch [49/100], Step [400/600], d_loss: 1.2839, g_loss: 1.4172, D(x): 0.62, D(G(z)): 0.54
# Epoch [49/100], Step [600/600], d_loss: 1.0682, g_loss: 0.6920, D(x): 0.57, D(G(z)): 0.39
# Saving fake_images-0050.png
# Epoch [50/100], Step [200/600], d_loss: 1.5054, g_loss: 0.3154, D(x): 0.59, D(G(z)): 0.61
# Epoch [50/100], Step [400/600], d_loss: 1.2852, g_loss: 1.2270, D(x): 0.57, D(G(z)): 0.50
# Epoch [50/100], Step [600/600], d_loss: 1.4656, g_loss: 0.7963, D(x): 0.58, D(G(z)): 0.59
# Saving fake_images-0051.png
# Epoch [51/100], Step [200/600], d_loss: 1.3087, g_loss: 0.7887, D(x): 0.59, D(G(z)): 0.53
# Epoch [51/100], Step [400/600], d_loss: 1.3799, g_loss: 0.7748, D(x): 0.53, D(G(z)): 0.50
# Epoch [51/100], Step [600/600], d_loss: 1.1510, g_loss: 0.8059, D(x): 0.67, D(G(z)): 0.52
# Saving fake_images-0052.png
# Epoch [52/100], Step [200/600], d_loss: 1.4247, g_loss: 0.8785, D(x): 0.73, D(G(z)): 0.66
# Epoch [52/100], Step [400/600], d_loss: 1.5440, g_loss: 1.0797, D(x): 0.36, D(G(z)): 0.37
# Epoch [52/100], Step [600/600], d_loss: 1.2391, g_loss: 0.8447, D(x): 0.58, D(G(z)): 0.49
# Saving fake_images-0053.png
# Epoch [53/100], Step [200/600], d_loss: 1.0127, g_loss: 0.6666, D(x): 0.71, D(G(z)): 0.48
# Epoch [53/100], Step [400/600], d_loss: 1.3311, g_loss: 0.8187, D(x): 0.36, D(G(z)): 0.23
# Epoch [53/100], Step [600/600], d_loss: 1.6456, g_loss: 0.6981, D(x): 0.48, D(G(z)): 0.58
# Saving fake_images-0054.png
# Epoch [54/100], Step [200/600], d_loss: 1.5460, g_loss: 0.9286, D(x): 0.36, D(G(z)): 0.39
# Epoch [54/100], Step [400/600], d_loss: 1.6956, g_loss: 1.0612, D(x): 0.44, D(G(z)): 0.57
# Epoch [54/100], Step [600/600], d_loss: 0.9805, g_loss: 1.0794, D(x): 0.54, D(G(z)): 0.29
# Saving fake_images-0055.png
# Epoch [55/100], Step [200/600], d_loss: 1.4843, g_loss: 0.5298, D(x): 0.44, D(G(z)): 0.46
# Epoch [55/100], Step [400/600], d_loss: 1.2577, g_loss: 0.5920, D(x): 0.67, D(G(z)): 0.57
# Epoch [55/100], Step [600/600], d_loss: 1.1530, g_loss: 1.1812, D(x): 0.67, D(G(z)): 0.52
# Saving fake_images-0056.png
# Epoch [56/100], Step [200/600], d_loss: 1.5463, g_loss: 1.2308, D(x): 0.49, D(G(z)): 0.55
# Epoch [56/100], Step [400/600], d_loss: 1.4005, g_loss: 1.0043, D(x): 0.75, D(G(z)): 0.66
# Epoch [56/100], Step [600/600], d_loss: 1.9954, g_loss: 1.2766, D(x): 0.32, D(G(z)): 0.55
# Saving fake_images-0057.png
# Epoch [57/100], Step [200/600], d_loss: 1.3316, g_loss: 0.6427, D(x): 0.45, D(G(z)): 0.40
# Epoch [57/100], Step [400/600], d_loss: 1.5212, g_loss: 1.1024, D(x): 0.44, D(G(z)): 0.49
# Epoch [57/100], Step [600/600], d_loss: 1.3874, g_loss: 0.5182, D(x): 0.71, D(G(z)): 0.64
# Saving fake_images-0058.png
# Epoch [58/100], Step [200/600], d_loss: 1.0213, g_loss: 0.8959, D(x): 0.62, D(G(z)): 0.41
# Epoch [58/100], Step [400/600], d_loss: 0.8567, g_loss: 0.9386, D(x): 0.75, D(G(z)): 0.43
# Epoch [58/100], Step [600/600], d_loss: 1.6809, g_loss: 0.6578, D(x): 0.59, D(G(z)): 0.67
# Saving fake_images-0059.png
# Epoch [59/100], Step [200/600], d_loss: 1.2782, g_loss: 1.0081, D(x): 0.47, D(G(z)): 0.40
# Epoch [59/100], Step [400/600], d_loss: 1.4138, g_loss: 1.2015, D(x): 0.55, D(G(z)): 0.55
# Epoch [59/100], Step [600/600], d_loss: 1.5479, g_loss: 0.7254, D(x): 0.44, D(G(z)): 0.50
# Saving fake_images-0060.png
# Epoch [60/100], Step [200/600], d_loss: 0.8134, g_loss: 1.4082, D(x): 0.64, D(G(z)): 0.30
# Epoch [60/100], Step [400/600], d_loss: 1.4977, g_loss: 1.1682, D(x): 0.74, D(G(z)): 0.69
# Epoch [60/100], Step [600/600], d_loss: 1.1128, g_loss: 0.6610, D(x): 0.75, D(G(z)): 0.55
# Saving fake_images-0061.png
# Epoch [61/100], Step [200/600], d_loss: 0.9917, g_loss: 0.5928, D(x): 0.61, D(G(z)): 0.38
# Epoch [61/100], Step [400/600], d_loss: 1.3645, g_loss: 0.4643, D(x): 0.41, D(G(z)): 0.35
# Epoch [61/100], Step [600/600], d_loss: 1.3082, g_loss: 0.6354, D(x): 0.47, D(G(z)): 0.40
# Saving fake_images-0062.png
# Epoch [62/100], Step [200/600], d_loss: 1.3374, g_loss: 0.5990, D(x): 0.66, D(G(z)): 0.59
# Epoch [62/100], Step [400/600], d_loss: 1.2280, g_loss: 0.8929, D(x): 0.60, D(G(z)): 0.50
# Epoch [62/100], Step [600/600], d_loss: 1.1195, g_loss: 0.6030, D(x): 0.68, D(G(z)): 0.51
# Saving fake_images-0063.png
# Epoch [63/100], Step [200/600], d_loss: 1.3175, g_loss: 0.8536, D(x): 0.42, D(G(z)): 0.36
# Epoch [63/100], Step [400/600], d_loss: 1.4617, g_loss: 0.7548, D(x): 0.67, D(G(z)): 0.64
# Epoch [63/100], Step [600/600], d_loss: 0.9299, g_loss: 0.5445, D(x): 0.69, D(G(z)): 0.42
# Saving fake_images-0064.png
# Epoch [64/100], Step [200/600], d_loss: 1.5413, g_loss: 0.9913, D(x): 0.54, D(G(z)): 0.59
# Epoch [64/100], Step [400/600], d_loss: 0.8958, g_loss: 0.7941, D(x): 0.72, D(G(z)): 0.42
# Epoch [64/100], Step [600/600], d_loss: 1.4115, g_loss: 0.7086, D(x): 0.49, D(G(z)): 0.49
# Saving fake_images-0065.png
# Epoch [65/100], Step [200/600], d_loss: 1.0521, g_loss: 0.8412, D(x): 0.65, D(G(z)): 0.45
# Epoch [65/100], Step [400/600], d_loss: 1.0720, g_loss: 0.9724, D(x): 0.56, D(G(z)): 0.37
# Epoch [65/100], Step [600/600], d_loss: 1.3019, g_loss: 0.7428, D(x): 0.66, D(G(z)): 0.58
# Saving fake_images-0066.png
# Epoch [66/100], Step [200/600], d_loss: 1.0926, g_loss: 0.5916, D(x): 0.55, D(G(z)): 0.38
# Epoch [66/100], Step [400/600], d_loss: 1.0323, g_loss: 1.1149, D(x): 0.54, D(G(z)): 0.33
# Epoch [66/100], Step [600/600], d_loss: 1.4508, g_loss: 1.2573, D(x): 0.60, D(G(z)): 0.60
# Saving fake_images-0067.png
# Epoch [67/100], Step [200/600], d_loss: 1.4392, g_loss: 0.8111, D(x): 0.43, D(G(z)): 0.43
# Epoch [67/100], Step [400/600], d_loss: 1.2192, g_loss: 0.6495, D(x): 0.40, D(G(z)): 0.24
# Epoch [67/100], Step [600/600], d_loss: 1.0993, g_loss: 0.9591, D(x): 0.58, D(G(z)): 0.41
# Saving fake_images-0068.png
# Epoch [68/100], Step [200/600], d_loss: 1.2879, g_loss: 0.4842, D(x): 0.40, D(G(z)): 0.29
# Epoch [68/100], Step [400/600], d_loss: 0.7940, g_loss: 0.3028, D(x): 0.71, D(G(z)): 0.36
# Epoch [68/100], Step [600/600], d_loss: 1.7016, g_loss: 0.7235, D(x): 0.31, D(G(z)): 0.38
# Saving fake_images-0069.png
# Epoch [69/100], Step [200/600], d_loss: 1.2521, g_loss: 0.7137, D(x): 0.77, D(G(z)): 0.62
# Epoch [69/100], Step [400/600], d_loss: 1.1999, g_loss: 0.5048, D(x): 0.51, D(G(z)): 0.39
# Epoch [69/100], Step [600/600], d_loss: 0.9583, g_loss: 1.2720, D(x): 0.65, D(G(z)): 0.40
# Saving fake_images-0070.png
# Epoch [70/100], Step [200/600], d_loss: 1.3974, g_loss: 1.2543, D(x): 0.41, D(G(z)): 0.38
# Epoch [70/100], Step [400/600], d_loss: 1.4289, g_loss: 0.8561, D(x): 0.68, D(G(z)): 0.64
# Epoch [70/100], Step [600/600], d_loss: 1.2522, g_loss: 0.7376, D(x): 0.52, D(G(z)): 0.43
# Saving fake_images-0071.png
# Epoch [71/100], Step [200/600], d_loss: 0.9773, g_loss: 0.7817, D(x): 0.66, D(G(z)): 0.42
# Epoch [71/100], Step [400/600], d_loss: 0.9853, g_loss: 0.7043, D(x): 0.53, D(G(z)): 0.28
# Epoch [71/100], Step [600/600], d_loss: 1.0785, g_loss: 0.4348, D(x): 0.58, D(G(z)): 0.41
# Saving fake_images-0072.png
# Epoch [72/100], Step [200/600], d_loss: 1.4578, g_loss: 1.0492, D(x): 0.63, D(G(z)): 0.62
# Epoch [72/100], Step [400/600], d_loss: 0.6173, g_loss: 1.0673, D(x): 0.81, D(G(z)): 0.33
# Epoch [72/100], Step [600/600], d_loss: 1.2923, g_loss: 1.3388, D(x): 0.43, D(G(z)): 0.34
# Saving fake_images-0073.png
# Epoch [73/100], Step [200/600], d_loss: 0.9054, g_loss: 0.8003, D(x): 0.62, D(G(z)): 0.34
# Epoch [73/100], Step [400/600], d_loss: 0.9352, g_loss: 0.7411, D(x): 0.67, D(G(z)): 0.40
# Epoch [73/100], Step [600/600], d_loss: 1.3569, g_loss: 0.9748, D(x): 0.54, D(G(z)): 0.51
# Saving fake_images-0074.png
# Epoch [74/100], Step [200/600], d_loss: 1.4000, g_loss: 0.9483, D(x): 0.49, D(G(z)): 0.48
# Epoch [74/100], Step [400/600], d_loss: 1.2612, g_loss: 0.8440, D(x): 0.41, D(G(z)): 0.29
# Epoch [74/100], Step [600/600], d_loss: 1.1548, g_loss: 0.6214, D(x): 0.39, D(G(z)): 0.16
# Saving fake_images-0075.png
# Epoch [75/100], Step [200/600], d_loss: 1.6323, g_loss: 1.6169, D(x): 0.44, D(G(z)): 0.53
# Epoch [75/100], Step [400/600], d_loss: 1.0038, g_loss: 1.3890, D(x): 0.62, D(G(z)): 0.39
# Epoch [75/100], Step [600/600], d_loss: 0.7569, g_loss: 0.9329, D(x): 0.63, D(G(z)): 0.25
# Saving fake_images-0076.png
# Epoch [76/100], Step [200/600], d_loss: 1.7029, g_loss: 1.1615, D(x): 0.41, D(G(z)): 0.54
# Epoch [76/100], Step [400/600], d_loss: 1.3348, g_loss: 1.2338, D(x): 0.67, D(G(z)): 0.60
# Epoch [76/100], Step [600/600], d_loss: 0.8845, g_loss: 0.9325, D(x): 0.63, D(G(z)): 0.33
# Saving fake_images-0077.png
# Epoch [77/100], Step [200/600], d_loss: 1.3219, g_loss: 1.5159, D(x): 0.48, D(G(z)): 0.43
# Epoch [77/100], Step [400/600], d_loss: 0.8129, g_loss: 0.6636, D(x): 0.65, D(G(z)): 0.31
# Epoch [77/100], Step [600/600], d_loss: 2.1188, g_loss: 1.1060, D(x): 0.17, D(G(z)): 0.27
# Saving fake_images-0078.png
# Epoch [78/100], Step [200/600], d_loss: 1.4826, g_loss: 0.4567, D(x): 0.45, D(G(z)): 0.48
# Epoch [78/100], Step [400/600], d_loss: 1.6153, g_loss: 0.7264, D(x): 0.36, D(G(z)): 0.42
# Epoch [78/100], Step [600/600], d_loss: 1.5875, g_loss: 0.6640, D(x): 0.65, D(G(z)): 0.68
# Saving fake_images-0079.png
# Epoch [79/100], Step [200/600], d_loss: 1.8872, g_loss: 0.3413, D(x): 0.47, D(G(z)): 0.66
# Epoch [79/100], Step [400/600], d_loss: 1.1937, g_loss: 1.0609, D(x): 0.41, D(G(z)): 0.25
# Epoch [79/100], Step [600/600], d_loss: 1.0853, g_loss: 1.1708, D(x): 0.75, D(G(z)): 0.54
# Saving fake_images-0080.png
# Epoch [80/100], Step [200/600], d_loss: 0.5890, g_loss: 0.7783, D(x): 0.75, D(G(z)): 0.25
# Epoch [80/100], Step [400/600], d_loss: 1.5478, g_loss: 1.4301, D(x): 0.33, D(G(z)): 0.33
# Epoch [80/100], Step [600/600], d_loss: 1.0648, g_loss: 0.4251, D(x): 0.58, D(G(z)): 0.39
# Saving fake_images-0081.png
# Epoch [81/100], Step [200/600], d_loss: 1.1446, g_loss: 1.6548, D(x): 0.56, D(G(z)): 0.42
# Epoch [81/100], Step [400/600], d_loss: 1.1986, g_loss: 0.5699, D(x): 0.65, D(G(z)): 0.53
# Epoch [81/100], Step [600/600], d_loss: 0.9330, g_loss: 0.4519, D(x): 0.71, D(G(z)): 0.43
# Saving fake_images-0082.png
# Epoch [82/100], Step [200/600], d_loss: 1.2024, g_loss: 0.5082, D(x): 0.59, D(G(z)): 0.48
# Epoch [82/100], Step [400/600], d_loss: 1.0354, g_loss: 0.8647, D(x): 0.65, D(G(z)): 0.45
# Epoch [82/100], Step [600/600], d_loss: 2.1065, g_loss: 1.4778, D(x): 0.43, D(G(z)): 0.70
# Saving fake_images-0083.png
# Epoch [83/100], Step [200/600], d_loss: 0.9830, g_loss: 0.4369, D(x): 0.55, D(G(z)): 0.31
# Epoch [83/100], Step [400/600], d_loss: 0.9376, g_loss: 1.0847, D(x): 0.63, D(G(z)): 0.37
# Epoch [83/100], Step [600/600], d_loss: 0.7160, g_loss: 0.8197, D(x): 0.65, D(G(z)): 0.24
# Saving fake_images-0084.png
# Epoch [84/100], Step [200/600], d_loss: 1.3781, g_loss: 0.8059, D(x): 0.37, D(G(z)): 0.30
# Epoch [84/100], Step [400/600], d_loss: 0.5913, g_loss: 1.1380, D(x): 0.65, D(G(z)): 0.15
# Epoch [84/100], Step [600/600], d_loss: 1.0840, g_loss: 0.6039, D(x): 0.74, D(G(z)): 0.54
# Saving fake_images-0085.png
# Epoch [85/100], Step [200/600], d_loss: 0.9746, g_loss: 0.6460, D(x): 0.60, D(G(z)): 0.36
# Epoch [85/100], Step [400/600], d_loss: 1.5588, g_loss: 0.6125, D(x): 0.44, D(G(z)): 0.51
# Epoch [85/100], Step [600/600], d_loss: 1.3550, g_loss: 1.5232, D(x): 0.40, D(G(z)): 0.35
# Saving fake_images-0086.png
# Epoch [86/100], Step [200/600], d_loss: 1.2060, g_loss: 0.4054, D(x): 0.54, D(G(z)): 0.44
# Epoch [86/100], Step [400/600], d_loss: 2.0255, g_loss: 0.6248, D(x): 0.40, D(G(z)): 0.65
# Epoch [86/100], Step [600/600], d_loss: 1.3923, g_loss: 0.9409, D(x): 0.38, D(G(z)): 0.32
# Saving fake_images-0087.png
# Epoch [87/100], Step [200/600], d_loss: 0.8550, g_loss: 0.5853, D(x): 0.52, D(G(z)): 0.17
# Epoch [87/100], Step [400/600], d_loss: 1.5493, g_loss: 0.5655, D(x): 0.67, D(G(z)): 0.68
# Epoch [87/100], Step [600/600], d_loss: 2.1979, g_loss: 0.8162, D(x): 0.19, D(G(z)): 0.38
# Saving fake_images-0088.png
# Epoch [88/100], Step [200/600], d_loss: 1.6054, g_loss: 0.4039, D(x): 0.65, D(G(z)): 0.68
# Epoch [88/100], Step [400/600], d_loss: 1.9445, g_loss: 1.1949, D(x): 0.33, D(G(z)): 0.55
# Epoch [88/100], Step [600/600], d_loss: 1.6126, g_loss: 0.3659, D(x): 0.36, D(G(z)): 0.43
# Saving fake_images-0089.png
# Epoch [89/100], Step [200/600], d_loss: 0.9154, g_loss: 0.5907, D(x): 0.57, D(G(z)): 0.29
# Epoch [89/100], Step [400/600], d_loss: 0.4683, g_loss: 0.8667, D(x): 0.80, D(G(z)): 0.22
# Epoch [89/100], Step [600/600], d_loss: 1.2409, g_loss: 0.8472, D(x): 0.66, D(G(z)): 0.56
# Saving fake_images-0090.png
# Epoch [90/100], Step [200/600], d_loss: 1.3732, g_loss: 0.4108, D(x): 0.74, D(G(z)): 0.65
# Epoch [90/100], Step [400/600], d_loss: 1.9028, g_loss: 0.4916, D(x): 0.37, D(G(z)): 0.58
# Epoch [90/100], Step [600/600], d_loss: 1.3361, g_loss: 1.2368, D(x): 0.37, D(G(z)): 0.26
# Saving fake_images-0091.png
# Epoch [91/100], Step [200/600], d_loss: 1.5443, g_loss: 0.7593, D(x): 0.43, D(G(z)): 0.48
# Epoch [91/100], Step [400/600], d_loss: 0.9223, g_loss: 0.7840, D(x): 0.78, D(G(z)): 0.48
# Epoch [91/100], Step [600/600], d_loss: 0.9526, g_loss: 0.7836, D(x): 0.74, D(G(z)): 0.47
# Saving fake_images-0092.png
# Epoch [92/100], Step [200/600], d_loss: 1.3264, g_loss: 1.1005, D(x): 0.53, D(G(z)): 0.49
# Epoch [92/100], Step [400/600], d_loss: 1.1521, g_loss: 1.1341, D(x): 0.58, D(G(z)): 0.44
# Epoch [92/100], Step [600/600], d_loss: 1.1357, g_loss: 0.6469, D(x): 0.46, D(G(z)): 0.29
# Saving fake_images-0093.png
# Epoch [93/100], Step [200/600], d_loss: 0.7366, g_loss: 0.8638, D(x): 0.81, D(G(z)): 0.40
# Epoch [93/100], Step [400/600], d_loss: 1.2844, g_loss: 0.3723, D(x): 0.44, D(G(z)): 0.36
# Epoch [93/100], Step [600/600], d_loss: 1.1263, g_loss: 1.0170, D(x): 0.59, D(G(z)): 0.44
# Saving fake_images-0094.png
# Epoch [94/100], Step [200/600], d_loss: 0.9212, g_loss: 1.4665, D(x): 0.57, D(G(z)): 0.30
# Epoch [94/100], Step [400/600], d_loss: 1.5348, g_loss: 1.5875, D(x): 0.53, D(G(z)): 0.58
# Epoch [94/100], Step [600/600], d_loss: 1.2143, g_loss: 0.5239, D(x): 0.52, D(G(z)): 0.42
# Saving fake_images-0095.png
# Epoch [95/100], Step [200/600], d_loss: 1.3330, g_loss: 0.8292, D(x): 0.80, D(G(z)): 0.66
# Epoch [95/100], Step [400/600], d_loss: 1.0757, g_loss: 1.5305, D(x): 0.58, D(G(z)): 0.40
# Epoch [95/100], Step [600/600], d_loss: 1.4782, g_loss: 1.0871, D(x): 0.55, D(G(z)): 0.58
# Saving fake_images-0096.png
# Epoch [96/100], Step [200/600], d_loss: 0.7560, g_loss: 1.1032, D(x): 0.67, D(G(z)): 0.29
# Epoch [96/100], Step [400/600], d_loss: 1.0497, g_loss: 1.4774, D(x): 0.48, D(G(z)): 0.26
# Epoch [96/100], Step [600/600], d_loss: 1.4367, g_loss: 0.5207, D(x): 0.43, D(G(z)): 0.43
# Saving fake_images-0097.png
# Epoch [97/100], Step [200/600], d_loss: 1.1649, g_loss: 0.9168, D(x): 0.62, D(G(z)): 0.48
# Epoch [97/100], Step [400/600], d_loss: 0.8595, g_loss: 1.0350, D(x): 0.60, D(G(z)): 0.28
# Epoch [97/100], Step [600/600], d_loss: 1.9649, g_loss: 0.8813, D(x): 0.47, D(G(z)): 0.69
# Saving fake_images-0098.png
# Epoch [98/100], Step [200/600], d_loss: 0.9550, g_loss: 0.8832, D(x): 0.59, D(G(z)): 0.33
# Epoch [98/100], Step [400/600], d_loss: 1.2464, g_loss: 1.2434, D(x): 0.46, D(G(z)): 0.37
# Epoch [98/100], Step [600/600], d_loss: 1.3108, g_loss: 0.7394, D(x): 0.44, D(G(z)): 0.37
# Saving fake_images-0099.png
# Epoch [99/100], Step [200/600], d_loss: 0.7917, g_loss: 0.7561, D(x): 0.64, D(G(z)): 0.29
# Epoch [99/100], Step [400/600], d_loss: 1.9800, g_loss: 0.4328, D(x): 0.24, D(G(z)): 0.41
# Epoch [99/100], Step [600/600], d_loss: 1.0994, g_loss: 0.4015, D(x): 0.51, D(G(z)): 0.33
# Saving fake_images-0100.png
# CPU times: user 1h 6min 55s, sys: 17min 2s, total: 1h 23min 57s
# Wall time: 1h 24min 10s

# %%
img = G.forward(torch.rand(1,64).to(device),torch.tensor([1]).to(device))

img = img.view(28,28).cpu().detach().numpy()

import matplotlib.pyplot as plt


plt.imshow(img)

# %%
# # Save the model checkpoints 
torch.save(G.state_dict(), 'G_CDCGAN_epochs_100.pt')
torch.save(D.state_dict(), 'D_CDCGAN_epochs_100.pt')

# %%
new_G = Generator_DCGAN()


new_G.load_state_dict(torch.load('G_CDCGAN_epochs_100.pt',map_location=torch.device('cpu')))

new_G.eval()
# Out:
# Generator_DCGAN(
#   (label_encoder): Embedding(10, 3136)
#   (l1): Linear(in_features=64, out_features=3136, bias=True)
#   (conv_blocks): Sequential(
#     (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Upsample(scale_factor=2.0, mode=nearest)
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): BatchNorm2d(128, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Upsample(scale_factor=2.0, mode=nearest)
#     (6): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(64, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): Tanh()
#   )
# )

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

print(sample_dir)
vid_fname = 'cgans_training.mp4'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink(vid_fname)
# Out:
# samples_cdcgan
# /content/cgans_training.mp4

# %% [markdown]
# You can view the animated training video here: https://www.youtube.com/watch?v=R7HTX79JlBg
#
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# ## Save and Commit
#
# We can caputre a snapshot of our work (including the Jupyter notebook, sample images and trained models) using the `jovian` Python library.

# %%
# Install the library
# !pip install jovian --upgrade -q
# Out:
#      |████████████████████████████████| 71kB 2.4MB/s
#   Building wheel for uuid (setup.py) ... done

# %%
# Import the library
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Error: Failed to detect Jupyter notebook or Python script. Skipping..

# %%
jovian.commit(outputs=['samples/fake_images-0000.png', 
                       'samples/fake_images-0010.png', 
                       'samples/fake_images-0025.png', 
                       'samples/fake_images-0050.png', 
                       'samples/fake_images-0100.png', 
                       'samples/fake_images-0150.png', 
                       'samples/fake_images-0200.png', 
                      ], 
              project='06-mnist-gan')
# Out:
# [jovian] Error: Failed to detect Jupyter notebook or Python script. Skipping..

# %% [markdown]
# Running `jovian.commit` uploads the Jupyter notebook and the associated files to your [Jovian.ml](https://www.jovian.ml) account. You can share the project online publicly, or collaborate privately with your friends & colleagues. Jovian also automatically captures the Python environment (dependencies & library versions), so that you & others can reproduce your work easily. Jovian also includes a powerful commenting interface for discussion. To learn more visit [www.jovian.ml](https://www.jovian.ml).
#
# <img src="https://i.imgur.com/KVjXpd6.png">
